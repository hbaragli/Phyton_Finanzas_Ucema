# %% [markdown]
# # Web Scraping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Cuestiones basicas

# %%
import requests

num=100
url = 'http://www.google.com/search?start=0&num='+str(num)+'&q=rofex'
html = requests.get(url)

print(html)
# Out:
# <Response [200]>

# %% [markdown]
# Que es ese objeto response?

# %%
html.text[:10000]
# Out:
# '<!doctype html><html lang="en"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>rofex - Google Search</title><script nonce="2b-wg_kJjY6F_yOQoVqToQ">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=function(g){g&&g.target.setAttribute("data-iml",String(Date.now()))};document.documentElement.addEventListener("load",h,!0);google.rglh=function(){document.documentElement.removeEventListener("load",h,!0)};}).call(this);(function(){window._skwEvts=[];})();(function(){window.google.erd={jsr:1,bv:1825,de:true};})();(function(){var sdo=false;var mei=10;\nvar l=this||self;var m,n=null!=(m=l.mei)?m:1,p,q=null!=(p=l.sdo)?p:!0,r=0,t,u=google.erd,v=u.jsr;google.ml=function(a,b,d,h,e){e=void 0===e?2:e;b&&(t=a&&a.message);if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||r>=n&&!h?!1:!0;if(!b)return null;r++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(u.jsr)+"&bver="+b(u.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=\na.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));c+="&cad=ple_"+google.ple;google.ple&&1===google.ple&&(e=2);c+="&jsel="+e;for(var k in d)c+="&",c+=b(k),c+="=",c+=b(d[k]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;h||google.log(0,"",a);return a};window.onerror=function(a,b,d,h,e){if(t!==a){a=e instanceof Error?e:Error(a);void 0===d||"lineNumber"in a||(a.lineNumber=d);void 0===b||"fileName"in a||(a.fileName=b);b=void 0;if(a.stack&&(-1!==a.stack.indexOf("?xjs=s0")||-1!==a.stack.indexOf("&xjs=s0"))){b=document.querySelectorAll("script[src*=\\\\/xjs\\\\/_\\\\/js\\\\/]");for(h=d=0;h<b.length;h++)d+=b[h].async?1:0;var c=e=h=-1,f=-1,g=-1;if(performance&&google.xjsu){h=0;e=google.timers.load.t.xjsee?1:0;f=c=0;g=performance.getEntriesByType("resource");for(var k=\n0;k<g.length;k++)g[k].name===google.xjsu&&(h=1),-1!==g[k].name.indexOf("/xjs/_/js/")&&(c+=1,f+="script"===g[k].initiatorType?1:0);g=c-f}b={cad:"pl_"+h+".pe_"+e+".asc_"+d+".tsc_"+b.length+".fasc_"+(b.length-d)+".lxc_"+c+".lsx_"+f+".lnsx_"+g}}google.ml(a,!1,b,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0)}t=null;q&&r>=n&&(window.onerror=null)};})();(function(){var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+Date.now());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);</script><style>a{color:#1a0dab;text-decoration:none;tap-highlight-color:rgba(0,0,0,.10)}a:visited{color:#4b11a8}a:hover{text-decoration:underline}img{border:0}html{font-family:arial,sans-serif;font-size:14px;line-height:20px;text-size-adjust:100%;color:#3c4043;word-wrap:break-word;background-color:#fff}.bRsWnc{background-color:#fff;border-top:1px solid #dadce0;height:39px;overflow:hidden}.N6RWV{height:51px;overflow-scrolling:touch ...

# %% [markdown]
# ## Librerias para scraping

# %%
from bs4 import BeautifulSoup

search = 'rofex'
start = 0
end = 50

agents = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
agents += "AppleWebKit/537.36 (KHTML, like Gecko) "
agents += "Chrome/91.0.4472.77 "
agents += "Safari/537.36"

h = {"user-agent": agents}

url = 'http://www.google.com/search?start='+str(start)+'&num='+str(end)+'&q='+search
html = requests.get(url, headers=h).text

soup = BeautifulSoup(html)

# Buscando todos los elementos de determinado TAG <h3> con una clase o id ".LC20lb DKV0Md"
titulos = soup.findAll("h3", {"class": "LC20lb MBeuO DKV0Md"})

# Por lista por comprension, con un selector css "div.yuRUbf > a"
links = [link['href'] for link in soup.select('div.yuRUbf > a')]

titulos[:20]
# Out:
# [<h3 class="LC20lb MBeuO DKV0Md">Rosario Futures Exchange (ROFEX) - US$/Argentine Peso</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba-Rofex: HOME</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Rosario Board of Trade</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba-Rofex</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Rosario Futures Exchange (ROFEX) - AFM</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Rosario Board of Trade - Wikipedia</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba Rofex S.A. (MTR.BA) Company Profile &amp; Facts</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Rofex</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba Rofex - Crunchbase Investor Profile &amp; Investments</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">ROFEX Company Profile: Valuation &amp; Investors</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">MTR Stock Price | Matba Rofex S.A. Stock Quote (Argentina</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba Rofex S.A. Company &amp; People | MTR</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Argentina Forex: Futures: ROFEX: United States Dollar</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">ROFEX Prices : Alexa Skills</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">ROFEX</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Working at Rofex</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba Rofex SA Stock Price Today | BA MTR Live Ticker</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Matba Rofex SA, MTR3:BUE summary - FT.com - Markets data</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Ultrafast electron beam X-ray computed tomography ...</h3>,
#  <h3 class="LC20lb MBeuO DKV0Md">Rofex 500mg Capsule: View Uses, Side Effects, Price and ...</h3>]

# %%
links[:30]
# Out:
# ['https://www.barchart.com/futures/prices-by-exchange/rofex',
#  'https://www.matbarofex.com.ar/',
#  'https://en.wikipedia.org/wiki/Rosario_Board_of_Trade',
#  'https://sseinitiative.org/derivative-exchange/matba-rofex/',
#  'https://www.afmorg.net/members/directory/ROFEX',
#  'https://en.wikipedia.org/wiki/Rosario_Board_of_Trade#:~:text=The%20Rosario%20Futures%20Exchange%20(ROFEX,rate%20and%20interest%20rate%20options.',
#  'https://finance.yahoo.com/quote/MTR.BA/profile/',
#  'https://www.coindesk.com/tag/rofex/',
#  'https://www.crunchbase.com/organization/matba-rofex',
#  'https://www.marketwatch.com/investing/stock/mtr?countrycode=ar',
#  'https://www.ceicdata.com/en/argentina/foreign-exchange-rates/forex-futures-rofex-united-states-dollar-1-month',
#  'https://www.barrons.com/market-data/stocks/mtr/company-people?countrycode=ar&mod=quotes',
#  'https://pitchbook.com/profiles/company/231906-25',
#  'https://markets.ft.com/data/equities/tearsheet/summary?s=MTR3:BUE',
#  'https://open.spotify.com/artist/4iNJchg538A1xm9cX8tlFm',
#  'https://www.hzdr.de/db/Cms?pOid=30242&pNid=393&pLang=en',
#  'https://matbarofex.primary.ventures/',
#  'https://www.glassdoor.com/Overview/Working-at-Rofex-EI_IE2253757.11,16.htm',
#  'https://www.investing.com/equities/matba-rofex',
#  'https://www.dnb.com/business-directory/company-profiles.matba_rofex_sa.be99166c629cfa3f4feefac3ac7c9e33.html',
#  'https://www.lybrate.com/medicine/rofex-500-mg-capsule',
#  'https://find-and-update.company-information.service.gov.uk/company/07434598',
#  'https://www.1mg.com/drugs/rofex-500mg-capsule-268269',
#  'https://soundcloud.com/profex-3',
#  'https://www.moneyland.ch/en/rosario-futures-exchange-rofex-definition',
#  'https://markets.businessinsider.com/stocks/matba_rofex-stock',
#  'https://github.com/topics/rofex?l=python',
#  'https://matbarofex.github.io/rRofex/',
#  'https://www.rofex.com.ar/cem/',
#  'https://www.zoominfo.com/c/matba-rofex-sa/480521040']

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_decode_markup',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %% [markdown]
# ## Con pandas

# %%
import pandas as pd

url = 'https://www.macrotrends.net/stocks/charts/AAPL/apple/price-book'
data = pd.read_html(url)[0]
data.columns = data.columns.droplevel()
data
# Out:
#           Date  Stock Price Book Value per Share  Price to Book Ratio
# 0   2023-07-10       188.61                  NaN                47.71
# 1   2023-03-31       164.67                $3.95                41.66
# 2   2022-12-31       129.55                $3.58                36.18
# 3   2022-09-30       137.57                $3.18                43.29
# 4   2022-06-30       135.91                $3.61                37.65
# 5   2022-03-31       173.32                $4.16                41.68
# 6   2021-12-31       176.03                $4.40                39.99
# 7   2021-09-30       140.07                $3.84                36.47
# 8   2021-06-30       135.37                $3.88                34.87
# 9   2021-03-31       120.53                $4.15                29.07
# 10  2020-12-31       130.74                $3.94                33.21
# 11  2020-09-30       113.91                $3.85                29.60
# 12  2020-06-30        89.54                $4.22                21.23
# 13  2020-03-31        62.25                $4.53                13.73
# 14  2019-12-31        71.71                $5.10                14.05
# 15  2019-09-30        54.53                $5.09                10.71
# 16  2019-06-30        48.01                $5.32                 9.02
# 17  2019-03-31        45.89                $5.74                 7.99
# 18  2018-12-31        37.95                $6.23                 6.09
# 19  2018-09-30        54.12                $5.63                 9.61
# 20  2018-06-30        44.22                $5.93                 7.45
# 21  2018-03-31        39.93                $6.42                 6.22
# 22  2017-12-31        40.11                $6.90                 5.82
# 23  2017-09-30        36.40                $6.54                 5.57
# 24  2017-06-30        33.88                $6.40                 5.29
# 25  2017-03-31        33.65                $6.44                 5.23
# 26  2016-12-31        27.02                $6.30                 4.29
# 27  2016-09-30        26.23                $6.01                 4.37
# 28  2016-06-30        22.07                $5.87                 3.76
# 29  2016-03-31        25.00                $5.95                 4.20
# 30  2015-12-31        24.02                $5.78                 4.15
# 31  2015-09-30        24.98                $5.35                 4.67
# 32  2015-06-30        28.37                $5.51                 5.15
# 33  2015-03-31        28.03                $5.60                 5.01
# 34  2014-12-31        24.77                $5.29                 4.68
# 35  2014-09-30        22.51                $4.75                 4.73
# 36  2014-06-30        20.66                $5.05                 4.09
# 37  2014-03-31        16.95                $4.98                 3.40
# 38  2013-12-31        17.61                $5.19                 3.39
# 39  2013-09-30        14.88                $4.91                 3.03
# 40  2013-06-30        12.29                $4.85                 2.54
# 41  2013-03-31        13.63                $5.15                 2.65
# 42  2012-12-31        16.30                $4.84                 3.36
# 43  2012-09-30        20.33                $4.50                 4.52
# 44  2012-06-30        17.73                $4.26                 4.16
# 45  2012-03-31        18.20                $3.92                 4.65
# 46  2011-12-31        12.29                $3.45                 3.56
# 47  2011-09-30        11.57                $2.94                 3.93
# 48  2011-06-30        10.19                $2.67                 3.81
# 49  2011-03-31        10.58                $2.37                 4.45
# 50  2010-12-31         9.79                $2.12                 4.62
# 51  2010-09-30         8.61                $1.86                 4.62
# 52  2010-06-30         7.63                $1.69                 4.53
# 53  2010-03-31         7.13                $1.54                 4.62
# 54  2009-12-31         6.40                $1.41                 4.54
# 55  2009-09-30         5.63                $1.26                 4.48
# 56  2009-06-30         4.32                $1.03                 4.19
# 57  2009-03-31         3.19                $0.97                 3.28

# %% [markdown]
# ## bs4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


r = requests.get("https://www.cronista.com")

soup = BeautifulSoup(r.content)

l = [link.text for link in soup.find_all('a') if len(link.text) > 50]
l[:30]
# Out:
# ['Gasoducto El "lado B" de la obra y la posibilidad de sustituir millones en importaciones',
#  'Data Gasoducto Néstor Kirchner: todos los números del proyecto clave para el gas de Vaca Muerta',
#  'Misión al FMI La discusión por los 3 tipos de dólar y la reunión que inquietó al mercado',
#  'Entrevista Jorge Macri se mide con Larreta y Mauricio y advierte a los piqueteros: "Van a tener conflicto conmigo"',
#  'ANSES Anuncio para jubilados y pensionados: a qué hora habla hoy Sergio Massa',
#  'Opinión ¿Desapareció el miedo a una inflación sin control?',
#  'El documental de Milei Mística libertaria y abucheos a "la casta": cómo se vivió el estreno\xa0',
#  'Jubilaciones La "buena noticia" que prepara Massa y que busca contener una caída histórica',
#  'Vaca Muerta Cuáles son las obras que se necesitarán en tiempo récord para evitar cortes de energía',
#  'Ley de Alquileres Las inmobiliarias piden al Gobierno que intervenga urgente',
#  'Nuevo rulo del dólar La ruta del dinero de los importadores truchos',
#  'En vivo Quiniela HOY: RESULTADOS de Nacional y Provincia del martes 11 de julio',
#  'ANSES Anuncio para jubilados y pensionados: a qué hora habla Sergio Massa hoy martes',
#  'La revolución liberal Mística libertaria y abucheos a "la casta": cómo se vivió el estreno del documental de Milei',
#  'Entrevista al candidato Jorge Macri se mide con Larreta y Mauricio y advierte a los piqueteros: "Van a tener conflicto conmigo"',
#  'Vaca Muerta Vista ya tiene más de 1000 pozos listos para producir en la formación',
#  'Caso Lucas González Cronología del crimen y cuándo se conocerá la sentencia final',
#  'Sustentabilidad Acciones concretas para minimizar el impacto ambiental: cuál es el rol de las energías limpias',
#  'Un hábito a incorporar Los sorprendentes beneficios de caminar dos minutos después de comer',
#  'Zoom editorial En economía los números no mienten, pero siempre hay más de una versión',
#  'Entrevista Petrobras: para el CEO que nombró Lula, no seguir buscando petróleo será la muerte de la empresa',
#  'FT Por qué la economía no responde al aumento de tasas de la Fed',
#  'FT Hay que terminar con la separación entre los bancos centrales y los gobiernos ',
#  'La bandera de "Los Monos": negocios de los barras, a sangre y fuego',
#  'Para completar la proeza del gasoducto, hay que lograr consenso en el Congreso',
#  'De Milei al PRO: denuncias, faltazos y renuncias en la guerra hacia las PASO ',
#  'Reforma laboral: una de las prioridades de Juntos por el Cambio si gana las elecciones',
#  'En el TEG del Conurbano, Santilli mueve sus fichas para la batalla más importante ',
#  'Bullrich: las clases en CABA y los estudiantes extranjeros en Argentina',
#  'Entrevista al candidato Jorge Macri se mide con Larreta y Mauricio y advierte a los piqueteros: "Van a tener conflicto conmigo"']

# %% [markdown]
# ## Scraping "mas complejo"

# %% [markdown]
# * Selenium: Se manipula al driver del navegador
#     * Se pueden desencadenar eventos
#     * Se puede manejar asincronismo
#     * Se hace creer al servidor que del otro lado hay un humano usando el navegador, basicamente no tiene forma de darse cuenta porque el script usa una GUI y una UX exactamente igual a la que usa un humano

# %% [markdown]
# * Ingeniería Inversa:
#     * Todas las páginas usan alguna tecnología para volcar datos en la inerfaz que ve el usuario (navegador), lo que pasa es que a veces no es instantáneo cuando se hace la primera petición al servidor, esto es por varios motivos:
#         * Streaming de datos en vivo
#         * Tecnologías que manipulan el DOM y dan feedback por ej REACT
#         * Asincronismo como por ej AJAX
#
#     La gracia entonces es ir yendo hacia atrás para ver cuando el navegador pide datos a algun servidor y logicamente encontrar que request hace y a que servidor

# %% [markdown]
# # Scraping vs APIs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Scraping
#
# Desventajas para el cliente:
#
#     * Mucho laburo preparar el barrido de datos, sujeto a errores y bugs
#     * Dificil mantenibilidad
#
#
# Desventajas para el Servidor:
#
#     * Consumo ineficiente de ancho de banda (se bajan muchos recursos innecesarios)
#     * Mala analítica de datos web (confunden tráfico con bots)
#
#
# ## APIs
#
# Ventajas para el cliente:
#
#     * Mas facil y rápidos requests
#     * Mejor mantenibilidad y escalabilidad de los proyectos
#
# Ventajas para el servidor:
#
#     * Integración horizontal de servicios web gracias a desarrollos de 3ros
#     * Mejor uso de recursos, mejor medición y control de analíticas de usuarios (gracias a API_Keys)

# %% [markdown]
# # APIs

# %% [markdown]
# Son un punete entre usuario/consumidor de datos y las bases de datos, no solo para lectura sino tambien escritura

# %% [markdown]
# ## Algunas Apis financieras

# %% [markdown]
# En las tablas me faltaron algunas muy piolas como:
#
#     * TDA Ameritrade: uno de los brokers mas grandes de USA, tiene opciones en real time
#     * Tiingo(webSocket de equity, fx y crypto)
#     * FED (Deuda, Securities: Bills/Notes/Bonds, Hojas de balances de a Fed etc)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Mas APIS

# %% [markdown]
# Algunos sitios que recopilan APIS
#
# * El repositorio publico de GitHub tiene listadas 1425 APIs al dia de hoy
#
#   https://github.com/public-apis/public-apis
#
#   Es un proyecto colaborativo con cientos de contribuidores
#
#
# * API List: Sitio web con aproximadamente 2000 APIs curadas en unas 100 categorías
#
#   https://www.apislist.com
#
#
# * OpenBB: Repo open source tipo terminal pero con fuentes de datos muy piolas
#
#   Aca hay que buscar la fuente manualmente
#
#   https://github.com/OpenBB-finance/OpenBBTerminal
#
#   Ejemplo opciones: https://github.com/OpenBB-finance/OpenBBTerminal/tree/develop/openbb_terminal/stocks/options

# %% [markdown]
# ### ¿Conviene usar una libreria o paquete o usar las APIs con funciones propias?

# %% [markdown]
# Conviene siempre, saber usar las APIs a "modo manual" es decir armando ustedes mismos las funciones y les pongo algunos por que:

# %% [markdown]
# #### Actualizacion
# * Porque a veces actualizan las APIs y no los paquetes, con lo cual nos perdemos "potencia" de API por usarla del paquete
# <br><br>
#
#
# #### Personalización y parametrización
# * Porque muchas veces necesitamos personalizar alguna función con algún parámetro extra que el paquete no lo brinda y nos terminamos limitando o haciendo un código menos eficiente
# <br><br>
#
#
# #### Mantenimiento y calidad
# * Porque si bien uno se puede fijar las "estrellas" que tiene el repositorio del paquete que baja, muchas veces tienen bugs que no se notan o no tiran error y puede ser un problemón

# %% [markdown]
# ### Tipos de APIs y Auth

# %% [markdown]
# * APIs públicas 100% (Fed)
#
#
# * APIs mixtas  (Típico de las APIs de cryptos)
#     * Endpoints públicos para marketData
#     * Endpoints privados para manejo de cuenta
#
#
# * APIs privadas
#     * Auth por token simple en request GET  (IEX, FPM, Alpha Vantage, Finnhub)
#     * Auth por token o par de tokens en encabezados con metodos POST o combinacion POST/GET  (Rofex)
#     * Auth con tokens que expiran cada tanto y hay que ir renovandolos  (IOL, Deribit)
#     * Auth con inicio de session (HitBTC)
#     * Auth con firma encriptada (FTX)

# %% [markdown]
# # Glosario básico

# %% [markdown]
# Acostúmbrense a esas palabritas porque las vamos a nombrar un montón a partir de ahora
# * Endpoint: Es una URL (dirección web) a la que vamos a apuntar para que me devuelva un dato
# * Llamados/Requests: Es la acción de entrar a esa URL
# * Response: Es la respuesta de la API a ese llamado
# * StatusCode: Es un código estandarizado que nos devuelve junto con el Response (abajo los explico mejor)
# * Servidor: Es la compu de la API
# * Cliente: Es la compu nuestra o nuestro programa que hace el request
# * Credenciales: Son las claves o tokens de autenticación
# * Body: Es el cuerpo de los mensajes (contenido) entre cliente y servidor
# * Headers: Son encabezados de los mensajes entre cliente y servidor (A veces aqui viajan las credenciales)
# * Parametros: Son justamente los parámetros (variables) que necesita el endpoint que le mandemos en el mensaje, hay  opcionales y obligatorios
# * SandBox: Son ambientes de prueba, para testear las funciones sin efecto real (como un simulador)
# * POST, GET, PATCH, DELETE, UPDATE: Son los principales métodos de comunicación cliente/servidor, a grandes rasgos GET es el mas comun, POST es mas seguro y se usa para autenticación o para envío de info sensible ya que cuando viaja por GET podría ser interceptada mas facilmente

# %% [markdown]
# ### Rate Limits

# %% [markdown]
# * Por dia, mes, semana
# * Por minuto, segundo
# * Ponderados según "peso" de cada endpoint
# * Por token o por IP

# %% [markdown]
# ### Status Code

# %% [markdown]
# Si bien ya vamos a ver mas adelante que pasa cuando falla una conexión y esas cosas, voy dejando por acá que es la parte de generalidades una tabla de códigos de respuesta Http, que nos devuelven todas las APIs a cada llamada salga bien o mal justamente diciendo eso (si salio bien o mal) y un mínimo estandar que nos orienta de donde está la falla en caso de haberla

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests

requests.get('https://google.com/cualquiera').status_code
# Out:
# 404

# %% [markdown]
# # API AlphaVantage

# %% [markdown]
# ## Leemos la documentacion

# %% [markdown]
# Ir a https://www.alphavantage.co y pedir su "api_key"

# %%
apikey = '2RG2NEF3IPXMIPX3'
apikey = '09QXTWMZ1UBWMPO8'
apikey = '09QXTWMZ1UBWMPO8'
apikey = 'N9P0QSV7X9VSJXV4'

# %% [markdown]
# ## Primer request a un endpoint

# %% [markdown]
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=15min&apikey=2RG2NEF3IPXMIPX3

# %% [markdown]
# Como verán es la serie de precios intradiarios, y me da una serie de parámetros obligatorios:
# * function: El nombre de la función (en esta API es obligatorio siempre este parámetro)
# * symbol: El ticker por ejemplo "AAPL"
# * interval: El intervalo entre cada vela (1min, 5min, 15min, 30min 60min)
# * apikey: Es nuestra clave, o token como definimos antes
# <br><br>Y una serie de parámetros optativos:
# * outputsize: Compacto o Full (aclara que  por default compacto devuelve solo 100 datos)
# * datatype: Nos da la posibilidad de descargarlo en un CSV (tipo excel) o devolver un JSON (texto que leerá python), por default es JSON y es lo que siempre vamos a usar, a menos que sen la API para descargarse excels, pero no tendría mucho sentido

# %% [markdown]
# Bueno, antes de codear esto, vamos a aclarar una cosa, como dijimos un request de una API REST es ni mas ni menos como visitar una pagina web, asi que estos parámetros los podríamos poner en la barra del navegador web y tendría que funcionar, veamos un ejemplo, vamos a usar esta API para saber los precios intradiarios de AAPL en velas de 15 minutos

# %% [markdown]
# LA URL base es: https://www.alphavantage.co/query

# %% [markdown]
# Luego le debemos poner los parámetros, para ello:
# * Al primer parámetro lo antecedemos por el signo "?"
# * Y para concaternar los otros usamos el signo "&"

# %% [markdown]
# Entonces la URL final quedaría asi:

# %% [markdown]
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=15min&apikey=2RG2NEF3IPXMIPX3

# %% [markdown]
# Así que veamos como sería eso, vamos a empezar por la manera mas burda de hacerlo y después lo emprolijamos
#
#
# Vamos a tener importar tres librerías:
#
#
# * requests: Para hacer el llamado HTTP a la API
# * pandas: Para guardar los datos en un DataFrame
#
#
# Obviamente solo necesito la librería requests para comunicarme con la API el resto es para trabajar con los datos que me devuelve

# %% [markdown]
# ## Armamos código o instrucciones para automatizar el request

# %%
#Importamos las librerías
import pandas as pd
import requests

#Definimos las variables (parámetros)
function = 'TIME_SERIES_INTRADAY'
symbol = 'AAPL'
interval = '15min'
token = "2RG2NEF3IPXMIPX3"


# https://www.alphavantage.co/query?
#function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&outputsize=full&apikey=demo

# Concateno la URL a visitar:
urlBase = 'https://www.alphavantage.co/query'
url = urlBase+'?function='+function
url += '&symbol='+ symbol
url += '&interval='+interval
url += '&outputsize=compact'
url += '&apikey='+token

# Acá hago el llamado/Request
r = requests.get(url)

print(r)
# Out:
# <Response [200]>

# %% [markdown]
# ## Inspeccionamos el response

# %% [markdown]
# Bien, pero lo que vemos ahi cuando imprimimos el response, ¿que es?
# <br>Es un objeto response de la librería requests, que obviamente tiene varios elementos y funciones:
# * text o content: Es el texto plano como lo vemos en la web
# * headers: Los encabezados
# * status_code: Como vimos el código que ya vimos que es 200, es decir que la comunicación esta ok
# * url: la url
# * cookies: Las cookies
# * json(): El método para obtener el objeto json, o diccionario del contenido

# %% [markdown]
# Veamos algun ejemplo:

# %%
r.url
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=15min&outputsize=compact&apikey=N9P0QSV7X9VSJXV4'

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Tue, 19 Jul 2022 16:48:46 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Cookie', 'X-Frame-Options': 'SAMEORIGIN', 'Allow': 'GET, HEAD, OPTIONS', 'Via': '1.1 vegur', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '72d4f250694069fa-MAD', 'Content-Encoding': 'gzip'}

# %% [markdown]
# ### Obtenemos la data que buscamos

# %%
print(r.text[:2000])
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Intraday (15min) open, high, low, close prices and volume",
#         "2. Symbol": "AAPL",
#         "3. Last Refreshed": "2023-07-10 19:45:00",
#         "4. Interval": "15min",
#         "5. Output Size": "Compact",
#         "6. Time Zone": "US/Eastern"
#     },
#     "Time Series (15min)": {
#         "2023-07-10 19:45:00": {
#             "1. open": "188.4600",
#             "2. high": "188.5900",
#             "3. low": "188.4500",
#             "4. close": "188.5900",
#             "5. volume": "10599"
#         },
#         "2023-07-10 19:30:00": {
#             "1. open": "188.5550",
#             "2. high": "188.6100",
#             "3. low": "188.4500",
#             "4. close": "188.4500",
#             "5. volume": "8851"
#         },
#         "2023-07-10 19:15:00": {
#             "1. open": "188.5650",
#             "2. high": "188.6100",
#             "3. low": "188.5050",
#             "4. close": "188.5100",
#             "5. volume": "8644"
#         },
#         "2023-07-10 19:00:00": {
#             "1. open": "188.5650",
#             "2. high": "188.6100",
#             "3. low": "188.5200",
#             "4. close": "188.5600",
#             "5. volume": "1978"
#         },
#         "2023-07-10 18:45:00": {
#             "1. open": "188.6500",
#             "2. high": "188.6500",
#             "3. low": "188.5100",
#             "4. close": "188.5650",
#             "5. volume": "3257"
#         },
#         "2023-07-10 18:30:00": {
#             "1. open": "188.5000",
#             "2. high": "188.6800",
#             "3. low": "188.5000",
#             "4. close": "188.6250",
#             "5. volume": "3961"
#         },
#         "2023-07-10 18:15:00": {
#             "1. open": "188.5250",
#             "2. high": "188.5800",
#             "3. low": "188.4700",
#             "4. close": "188.5010",
#             "5. volume": "5978"
#         },
#         "2023-07-10 18:00:00": {
#             "1. open": "188.5400",
#             "2. high": "188.6200",
#             "3. low": "188.4500",
#             "4. clo

# %% [markdown]
# ### La pasamos a un formato manipulable

# %%
r.json().keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (15min)'])

# %%
mi_dicc = r.json()

# %%
mi_dicc['Meta Data']
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2022-07-18 20:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
i = 0
for item in mi_dicc['Time Series (15min)'].items():
  print(item)
  i += 1
  if i >= 5:
    break
# Out:
# ('2023-07-10 19:45:00', {'1. open': '188.4600', '2. high': '188.5900', '3. low': '188.4500', '4. close': '188.5900', '5. volume': '10599'})
# ('2023-07-10 19:30:00', {'1. open': '188.5550', '2. high': '188.6100', '3. low': '188.4500', '4. close': '188.4500', '5. volume': '8851'})
# ('2023-07-10 19:15:00', {'1. open': '188.5650', '2. high': '188.6100', '3. low': '188.5050', '4. close': '188.5100', '5. volume': '8644'})
# ('2023-07-10 19:00:00', {'1. open': '188.5650', '2. high': '188.6100', '3. low': '188.5200', '4. close': '188.5600', '5. volume': '1978'})
# ('2023-07-10 18:45:00', {'1. open': '188.6500', '2. high': '188.6500', '3. low': '188.5100', '4. close': '188.5650', '5. volume': '3257'})

# %% [markdown]
# ### La pasamos a dataframe

# %%
datos = r.json()['Time Series (15min)']

pd.DataFrame(datos).transpose()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2023-07-10 19:45:00  188.4600  188.5900  188.4500  188.5900     10599
# 2023-07-10 19:30:00  188.5550  188.6100  188.4500  188.4500      8851
# 2023-07-10 19:15:00  188.5650  188.6100  188.5050  188.5100      8644
# 2023-07-10 19:00:00  188.5650  188.6100  188.5200  188.5600      1978
# 2023-07-10 18:45:00  188.6500  188.6500  188.5100  188.5650      3257
# ...                       ...       ...       ...       ...       ...
# 2023-07-07 12:00:00  191.7600  192.2100  191.7600  192.1200   1823576
# 2023-07-07 11:45:00  191.5450  191.7800  191.4700  191.7530   1226897
# 2023-07-07 11:30:00  191.2100  191.5500  191.1850  191.5500   1185011
# 2023-07-07 11:15:00  190.9600  191.2900  190.8500  191.2100   1058135
# 2023-07-07 11:00:00  190.6800  191.0500  190.6750  190.9600   1044402
#
# [100 rows x 5 columns]

# %%
data = r.json()['Time Series (15min)']
dataDF = pd.DataFrame.from_dict(data, orient='index')
dataDF
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2022-07-18 20:00:00  147.0000  147.0000  146.7600  146.9000     25821
# 2022-07-18 19:45:00  146.8800  147.0000  146.3000  146.9500     37195
# 2022-07-18 19:30:00  146.6000  146.8900  146.6000  146.8700     23718
# 2022-07-18 19:15:00  146.7300  146.7300  146.4500  146.6000     16569
# 2022-07-18 19:00:00  146.7100  146.7500  146.6800  146.7300     10270
# ...                       ...       ...       ...       ...       ...
# 2022-07-15 12:15:00  148.7900  148.8600  148.2000  148.5488   2413312
# 2022-07-15 12:00:00  149.1450  149.3650  148.7900  148.7910   1625986
# 2022-07-15 11:45:00  149.0400  149.2200  148.9200  149.1500   1852250
# 2022-07-15 11:30:00  149.5000  149.5700  149.0250  149.0400   1350919
# 2022-07-15 11:15:00  149.2500  149.6300  149.1197  149.5000   2119062
#
# [100 rows x 5 columns]

# %% [markdown]
# ## ¿QUE FALTA?

# %% [markdown]
# * Emprolijar código
# * Mecanismo para evitar errores (API/Usuario)
# * Meter todo el código en una función
# * Que el dataframe esté ordenado cronologicamente
# * Que el dataframe tenga valores numéricos
# * Estandarizar los nombres de columnas del dataframe

# %% [markdown]
# ### Emprolijamos el código

# %% [markdown]
# Pasando en limpio un poco el código, en lugar de concatenar la URL entera con todos los parámetros, lo que podemos hacer, y es una buena práctica hacer, es mandar todos los parámetros como parámetros del rrequest en lugar de mandarlos concatenando la URL

# %%
function = 'TIME_SERIES_INTRADAY'
symbol = 'AAPL'
interval = '15min'
size = 'compact'
token = "2RG2NEF3IPXMIPX3"

url = 'https://www.alphavantage.co/query'

parametros = {'function' : function, 'symbol': symbol, 'interval': interval,
              'outputsize': size, 'apikey': token}

# r = requests.get(url, data = parametros)
# r = requests.get(url, json = parametros)
r = requests.get(url, params=parametros)

data = r.json()['Time Series (15min)']
dataDF = pd.DataFrame.from_dict(data, orient='index')
dataDF
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2023-07-10 19:45:00  188.4600  188.5900  188.4500  188.5900     10599
# 2023-07-10 19:30:00  188.5550  188.6100  188.4500  188.4500      8851
# 2023-07-10 19:15:00  188.5650  188.6100  188.5050  188.5100      8644
# 2023-07-10 19:00:00  188.5650  188.6100  188.5200  188.5600      1978
# 2023-07-10 18:45:00  188.6500  188.6500  188.5100  188.5650      3257
# ...                       ...       ...       ...       ...       ...
# 2023-07-07 12:00:00  191.7600  192.2100  191.7600  192.1200   1823576
# 2023-07-07 11:45:00  191.5450  191.7800  191.4700  191.7530   1226897
# 2023-07-07 11:30:00  191.2100  191.5500  191.1850  191.5500   1185011
# 2023-07-07 11:15:00  190.9600  191.2900  190.8500  191.2100   1058135
# 2023-07-07 11:00:00  190.6800  191.0500  190.6750  190.9600   1044402
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Provoquemos error con el timeframe

# %%
function = 'TIME_SERIES_INTRADAY'
symbol = 'AAPL'
interval = '5min'
size = 'compact'
token = "2RG2NEF3IPXMIPX3"

url = 'https://www.alphavantage.co/query'

parametros = {'function' : function, 'symbol': symbol, 'interval': interval,
              'outputsize': size, 'apikey': token}

# r = requests.get(url, data = parametros)
# r = requests.get(url, json = parametros)
r = requests.get(url, params=parametros)

data = r.json()['Time Series (15min)']
dataDF = pd.DataFrame.from_dict(data, orient='index')
dataDF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f1dce613e08c> in <cell line: 16>()
#      14 r = requests.get(url, params=parametros)
#      15
# ---> 16 data = r.json()['Time Series (15min)']
#      17 dataDF = pd.DataFrame.from_dict(data, orient='index')
#      18 dataDF
#
# KeyError: 'Time Series (15min)'

# %%
function = 'TIME_SERIES_INTRADAY'
symbol = 'AAPL'
interval = '5min'
size = 'compact'
token = "2RG2NEF3IPXMIPX3"

url = 'https://www.alphavantage.co/query'

parametros = {'function' : function, 'symbol': symbol, 'interval': interval,
              'outputsize': size, 'apikey': token}

# r = requests.get(url, data = parametros)
# r = requests.get(url, json = parametros)
r = requests.get(url, params=parametros)

data = r.json()[f'Time Series ({interval})']
dataDF = pd.DataFrame.from_dict(data, orient='index')
dataDF
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2023-07-10 19:55:00  188.5200  188.5900  188.4600  188.5900      5394
# 2023-07-10 19:50:00  188.4900  188.5800  188.4500  188.4600      3617
# 2023-07-10 19:45:00  188.4600  188.5200  188.4500  188.5200      1588
# 2023-07-10 19:40:00  188.4700  188.4800  188.4500  188.4500      1486
# 2023-07-10 19:35:00  188.5700  188.6000  188.4500  188.4800      5279
# ...                       ...       ...       ...       ...       ...
# 2023-07-10 12:00:00  187.5210  187.5850  187.2100  187.3350    990180
# 2023-07-10 11:55:00  187.7850  187.9200  187.5200  187.5300    489280
# 2023-07-10 11:50:00  187.7200  187.9840  187.7200  187.7850    481936
# 2023-07-10 11:45:00  187.9600  187.9750  187.6000  187.7290    658565
# 2023-07-10 11:40:00  188.3500  188.4510  187.9600  187.9600    755582
#
# [100 rows x 5 columns]

# %% [markdown]
# Y para terminar lo podemos meter en una función

# %% [markdown]
# ### Arreglamos el error del intervalo o timeframe en forma genérica

# %%
def getIntra(function, symbol, size, token, t):

    """
    params:
        t: Es el tiempo en minutos, valores posibles 1, 5, 15, 30, 60
        size: puede ser compact (100 datos) o full (todo lo que tenga la aPI)
    """

    interval = f"{t}min"
    url = 'https://www.alphavantage.co/query'

    parametros = {'function' : function, 'symbol': symbol, 'interval': interval,
                  'outputsize': size, 'apikey': token}

    r = requests.get(url, params=parametros)
    data = r.json()[f'Time Series ({interval})']
    dataDF = pd.DataFrame.from_dict(data, orient='index')

    return dataDF

# %%
help(getIntra)
# Out:
# Help on function getIntra in module __main__:
#
# getIntra(function, symbol, size, token, t)
#     params:
#         t: Es el tiempo en minutos, valores posibles 1, 5, 15, 30, 60
#         size: puede ser compact (100 datos) o full (todo lo que tenga la aPI)

# %%
data = getIntra(function="TIME_SERIES_INTRADAY", symbol="YPF", t=15, size="compact", token=token)
data
# Out:
#                      1. open  2. high   3. low 4. close 5. volume
# 2023-07-10 19:30:00  14.4600  14.4600  14.4200  14.4200       100
# 2023-07-10 19:00:00  14.5100  14.5100  14.4600  14.4600     43771
# 2023-07-10 18:30:00  14.5100  14.5100  14.5100  14.5100     43741
# 2023-07-10 17:45:00  14.5600  14.5600  14.5600  14.5600        15
# 2023-07-10 17:30:00  14.4600  14.4600  14.4600  14.4600         1
# ...                      ...      ...      ...      ...       ...
# 2023-07-06 13:45:00  14.1000  14.1700  14.0800  14.1200     79077
# 2023-07-06 13:30:00  13.9700  14.1100  13.9350  14.0900    109250
# 2023-07-06 13:15:00  13.9300  14.0400  13.9250  13.9750    111348
# 2023-07-06 13:00:00  14.0050  14.0200  13.9260  13.9300    169618
# 2023-07-06 12:45:00  14.0100  14.0550  13.9800  14.0000     93203
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Provoquemos otro error...

# %%
# Le vamos a mandar un ticker mal tipeado
data = getIntra(function='TIME_SERIES_INTRADAY', symbol='AAAPL', t=5,
                size='compact', token="2RG2NEF3IPXMIPX3")

data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-ab29f00ad5de> in <cell line: 1>()
# ----> 1 data = getIntra(function='TIME_SERIES_INTRADAY', symbol='AAAPL', t=5,
#       2                 size='compact', token="2RG2NEF3IPXMIPX3")
#       3
#       4 data
#
# <ipython-input-15-d01c19677bc6> in getIntra(function, symbol, size, token, t)
#      14
#      15     r = requests.get(url, params=parametros)
# ---> 16     data = r.json()[f'Time Series ({interval})']
#      17     dataDF = pd.DataFrame.from_dict(data, orient='index')
#      18
#
# KeyError: 'Time Series (5min)'

# %% [markdown]
# ¿Soluciones?  escucho ideas..

# %%
def getIntra(function, symbol, size, token, t):

    """
    params:
        t: Es el tiempo en minutos, valores posibles 1, 5, 15, 30, 60
        size: puede ser compact (100 datos) o full (todo lo que tenga la aPI)
    """

    interval = f"{t}min"
    url = 'https://www.alphavantage.co/query'

    parametros = {'function' : function, 'symbol': symbol, 'interval': interval,
                  'outputsize': size, 'apikey': token}

    r = requests.get(url, params=parametros)

    try:
        data = r.json()[f'Time Series ({interval})']
        dataDF = pd.DataFrame.from_dict(data, orient='index')
    except:
        dataDF = pd.DataFrame()
        print('Ojo que esta fallando el request \n\nRespuesta de la API:\n', r.text)

    return dataDF

# %%
data = getIntra(function='TIME_SERIES_INTRADAY', symbol='adasdasd', t=5,
                size='compact', token="2RG2NEF3IPXMIPX3")

data
# Out:
# Ojo que esta fallando el request
#
# Respuesta de la API:
#  {
#     "Error Message": "Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_INTRADAY."
# }
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Ojo siempre con los tipos

# %%
data = getIntra(function='TIME_SERIES_INTRADAY', symbol='AAPL', t=5,
                size='compact', token="2RG2NEF3IPXMIPX3")

data.round(2).head()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2023-07-10 19:55:00  188.5200  188.5900  188.4600  188.5900      5394
# 2023-07-10 19:50:00  188.4900  188.5800  188.4500  188.4600      3617
# 2023-07-10 19:45:00  188.4600  188.5200  188.4500  188.5200      1588
# 2023-07-10 19:40:00  188.4700  188.4800  188.4500  188.4500      1486
# 2023-07-10 19:35:00  188.5700  188.6000  188.4500  188.4800      5279

# %% [markdown]
# ¿Que onda? no redondéo nada..

# %%
# De que tipo es la data?

type(data.iloc[0]['1. open'])
# Out:
# str

# %%
data = data.astype('float')

data.round(1).head()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# 2023-07-10 19:55:00    188.5    188.6   188.5     188.6     5394.0
# 2023-07-10 19:50:00    188.5    188.6   188.4     188.5     3617.0
# 2023-07-10 19:45:00    188.5    188.5   188.4     188.5     1588.0
# 2023-07-10 19:40:00    188.5    188.5   188.4     188.4     1486.0
# 2023-07-10 19:35:00    188.6    188.6   188.4     188.5     5279.0

# %%
pd.to_numeric(data['5. volume'])
# Out:
# 2023-07-10 19:55:00      5394.0
# 2023-07-10 19:50:00      3617.0
# 2023-07-10 19:45:00      1588.0
# 2023-07-10 19:40:00      1486.0
# 2023-07-10 19:35:00      5279.0
#                          ...
# 2023-07-10 12:00:00    990180.0
# 2023-07-10 11:55:00    489280.0
# 2023-07-10 11:50:00    481936.0
# 2023-07-10 11:45:00    658565.0
# 2023-07-10 11:40:00    755582.0
# Name: 5. volume, Length: 100, dtype: float64

# %%
data = getIntra(function='TIME_SERIES_INTRADAY', symbol='AAPL', t=5,
                size='compact', token="2RG2NEF3IPXMIPX3")

data.apply(pd.to_numeric)
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# 2023-07-10 19:55:00  188.520  188.590  188.46   188.590       5394
# 2023-07-10 19:50:00  188.490  188.580  188.45   188.460       3617
# 2023-07-10 19:45:00  188.460  188.520  188.45   188.520       1588
# 2023-07-10 19:40:00  188.470  188.480  188.45   188.450       1486
# 2023-07-10 19:35:00  188.570  188.600  188.45   188.480       5279
# ...                      ...      ...     ...       ...        ...
# 2023-07-10 12:00:00  187.521  187.585  187.21   187.335     990180
# 2023-07-10 11:55:00  187.785  187.920  187.52   187.530     489280
# 2023-07-10 11:50:00  187.720  187.984  187.72   187.785     481936
# 2023-07-10 11:45:00  187.960  187.975  187.60   187.729     658565
# 2023-07-10 11:40:00  188.350  188.451  187.96   187.960     755582
#
# [100 rows x 5 columns]

# %% [markdown]
# # Tips para descargar series de datos de precios de activos

# %% [markdown]
# * TIPOS NUMERICOS, estandarizar decimmales
#
#
# * ORDEN (creciente)
#
#
# * NOMBRES COLUMNAS (Open, High, Low, Close, Volume, VolumeUsd, pctChange)
#
#
# * INDICE TIPO FECHA?
#
#
# * FUNCION O PARAMETROS AL PEDO

# %%
def getIntra(symbol, t, size='full'):

    """
    params:
        t: Es el tiempo en minutos, valores posibles 1, 5, 15, 30, 60
        size: puede ser compact (100 datos) o full (todo lo que tenga la aPI), por default es full
    """

    interval = f"{t}min"
    url = 'https://www.alphavantage.co/query'

    parametros = {'function' : 'TIME_SERIES_INTRADAY', 'symbol': symbol,
                  'interval': interval, 'outputsize': size, 'apikey': token}

    r = requests.get(url, params=parametros)

    try:
        data = r.json()[f'Time Series ({interval})']
        df = pd.DataFrame.from_dict(data, orient='index')
        df.index.name = 'Date'
        df.columns = ['Open','High','Low','Close','Volume']
        df = df.apply(pd.to_numeric)
        df.index = pd.to_datetime(df.index)
        df.sort_index(inplace=True)
        df['DailyChange'] = df.Close.pct_change()
        df.dropna(inplace=True)
    except:
        df = pd.DataFrame()
        print('Ojo que esta fallando el request \n\nRespuesta de la API:\n', r.text)

    return df

# %%
getIntra('AAPL', 5)
# Out:
#                        Open    High     Low   Close  Volume  DailyChange
# Date
# 2022-06-21 04:10:00  134.70  134.70  134.43  134.48    6120    -0.001559
# 2022-06-21 04:15:00  134.49  134.70  134.46  134.55   12730     0.000521
# 2022-06-21 04:20:00  134.56  134.56  134.31  134.48   18509    -0.000520
# 2022-06-21 04:25:00  134.45  134.59  134.45  134.59   11703     0.000818
# 2022-06-21 04:30:00  134.59  134.65  134.46  134.46    7267    -0.000966
# ...                     ...     ...     ...     ...     ...          ...
# 2022-07-18 19:40:00  146.76  147.00  146.76  146.93    8342     0.000068
# 2022-07-18 19:45:00  146.93  147.00  146.90  146.95   13118     0.000136
# 2022-07-18 19:50:00  147.00  147.00  146.85  146.88    9207    -0.000476
# 2022-07-18 19:55:00  146.84  146.90  146.84  146.90    7882     0.000136
# 2022-07-18 20:00:00  146.94  146.94  146.76  146.90    8732     0.000000
#
# [3569 rows x 6 columns]

# %% [markdown]
# # Scraping por ing inversa

# %% [markdown]
# https://www.byma.com.ar

# %%
import requests
import pandas as pd

# %%
# SSLError: HTTPSConnectionPool(host='www.byma.com.ar', port=443) => verify=False

# %%
url = 'https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_montos'
agents = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
agents += "AppleWebKit/537.36 (KHTML, like Gecko) "
agents += "Chrome/91.0.4472.77 "
agents = "Safari/537.36"
h = {"user-agent": agents}

r = requests.get(url, headers=h, verify=False)
r.json()
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.byma.com.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'MensajeNro': 836060,
#  'Montos': {'Cauciones': {'Monto': 397516191237, 'Porcentaje': 31.15},
#   'Futuros': {'Monto': 0, 'Porcentaje': 0},
#   'Opciones': {'Monto': 393695708, 'Porcentaje': 0.03},
#   'Pase_Colocador': 0,
#   'Pase_Tomador': 0,
#   'Prestamos_Titulos_Publicos': {'Monto': 648289693, 'Porcentaje': 0.05},
#   'Renta_Fija': {'Piso_SINAC': {'Obligaciones_Negociables': {'Monto': 20627740047,
#      'Porcentaje': 1.62},
#     'Titulos_Publicos': {'Monto': 307117822350, 'Porcentaje': 24.07}},
#    'Sesion_Continua': {'Obligaciones_Negociables': {'Monto': 121217912155,
#      'Porcentaje': 9.5},
#     'Titulos_Publicos': {'Monto': 413330723230, 'Porcentaje': 32.39}}},
#   'Total_Negociado_Acciones': {'Acciones': {'Monto': 5590743967,
#     'Porcentaje': 0.44},
#    'Cedears': {'Monto': 9512641086, 'Porcentaje': 0.75},
#    'Ejercicios': {'Monto': 14832032, 'Porcentaje': 0},
#    'Sesion_Continua': {'Monto': 0, 'Porcentaje': 0}},
#   'Total_Negociado_BCBA': {'Monto': 1275970591505, 'Porcentaje': 100}}}

# %%
import warnings
warnings.filterwarnings('ignore')


def scrapByma(params):
    url = 'https://www.byma.com.ar/wp-admin/admin-ajax.php'
    agents = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    agents += "AppleWebKit/537.36 (KHTML, like Gecko) "
    agents += "Chrome/91.0.4472.77 "
    agents = "Safari/537.36"
    h = {"user-agent": agents}

    r = requests.get(url, params=params, headers=h, verify=False)
    return r.json()

# %%
params = {"action":"get_panel", "panel_id":"4"}

pd.options.display.max_columns = 8
pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')
# Out:
#             Apertura  Cantidad_Nominal_Compra  Cantidad_Nominal_Venta  \
# Simbolo
# ALUC155.AG    236.21                        2                      17
# ALUC170.AG    227.00                       30                      50
# ALUC175.AG      0.00                       30                     100
# ALUC190.AG      0.00                       30                       1
# ALUC210.AG      0.00                       30                     108
# ...              ...                      ...                     ...
# YPFV7300DI      0.00                        1                       0
# YPFV7300OC      0.00                        5                       0
# YPFV7600AG    320.00                        3                       4
# YPFV7900AG      0.00                        0                       1
# YPFV8200AG      0.00                        1                       1
#
#            Cantidad_Operaciones  ...  Ultimo Variacion Vencimiento  \
# Simbolo                          ...
# ALUC155.AG                    2  ...   236.5      2.83         N/A
# ALUC170.AG                    9  ...   228.0      2.24         N/A
# ALUC175.AG                       ...     0.0      0.00         N/A
# ALUC190.AG                       ...     0.0      0.00         N/A
# ALUC210.AG                       ...     0.0      0.00         N/A
# ...                         ...  ...     ...       ...         ...
# YPFV7300DI                       ...     0.0      0.00         N/A
# YPFV7300OC                       ...     0.0      0.00         N/A
# YPFV7600AG                   10  ...   329.5      9.83         N/A
# YPFV7900AG                       ...     0.0      0.00         N/A
# YPFV8200AG                       ...     0.0      0.00         N/A
#
#            Volumen_Nominal
# Simbolo
# ALUC155.AG               4
# ALUC170.AG             559
# ALUC175.AG               0
# ALUC190.AG               0
# ALUC210.AG               0
# ...                    ...
# YPFV7300DI               0
# YPFV7300OC               0
# YPFV7600AG              11
# YPFV7900AG               0
# YPFV8200AG               0
#
# [694 rows x 22 columns]

# %% [markdown]
# # EndPoints Byma

# %% [markdown]
# * Volumenes: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_montos
# * Acciones: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=0
# * Galpones: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=2
# * Opciones: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=4
# * CEDEARs: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=5
# * Bonos: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=7
# * ONs: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_panel&panel_id=11
# * Detalle Instrumento: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_simbolo&simbolo=BYMA&panel=2
# * Indices: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_ticker
# * Futuros: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_futuros_b3
# * Bslance Sheet: https://www.byma.com.ar/wp-admin/admin-ajax.php?action=get_balance_simbolo&simbolo=CTIO

# %%
params = {"action":"get_panel", "panel_id":"4"}

pd.options.display.max_columns = 8
data = pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')
data
# Out:
#             Apertura  Cantidad_Nominal_Compra  Cantidad_Nominal_Venta  \
# Simbolo
# ALUC155.AG    236.21                        2                      17
# ALUC170.AG    227.00                       30                      50
# ALUC175.AG      0.00                       30                     100
# ALUC190.AG      0.00                       30                       1
# ALUC210.AG      0.00                       30                     108
# ...              ...                      ...                     ...
# YPFV7300DI      0.00                        1                       0
# YPFV7300OC      0.00                        5                       0
# YPFV7600AG    320.00                        3                       4
# YPFV7900AG      0.00                        0                       1
# YPFV8200AG      0.00                        1                       1
#
#            Cantidad_Operaciones  ...  Ultimo Variacion Vencimiento  \
# Simbolo                          ...
# ALUC155.AG                    2  ...   236.5      2.83         N/A
# ALUC170.AG                    9  ...   228.0      2.24         N/A
# ALUC175.AG                       ...     0.0      0.00         N/A
# ALUC190.AG                       ...     0.0      0.00         N/A
# ALUC210.AG                       ...     0.0      0.00         N/A
# ...                         ...  ...     ...       ...         ...
# YPFV7300DI                       ...     0.0      0.00         N/A
# YPFV7300OC                       ...     0.0      0.00         N/A
# YPFV7600AG                   10  ...   329.5      9.83         N/A
# YPFV7900AG                       ...     0.0      0.00         N/A
# YPFV8200AG                       ...     0.0      0.00         N/A
#
#            Volumen_Nominal
# Simbolo
# ALUC155.AG               4
# ALUC170.AG             559
# ALUC175.AG               0
# ALUC190.AG               0
# ALUC210.AG               0
# ...                    ...
# YPFV7300DI               0
# YPFV7300OC               0
# YPFV7600AG              11
# YPFV7900AG               0
# YPFV8200AG               0
#
# [694 rows x 22 columns]

# %%
data.iloc[0]
# Out:
# Apertura                       236.21
# Cantidad_Nominal_Compra             2
# Cantidad_Nominal_Venta             17
# Cantidad_Operaciones                2
# Cierre_Anterior                 230.0
# Denominacion
# Estado
# Ex                                 No
# Hora_Cotizacion              16:57:49
# Maximo                          236.5
# Minimo                         236.21
# Monto_Operado_Pesos             94542
# Precio_Compra                     2.0
# Precio_Promedio               236.355
# Precio_Promedio_Ponderado    236.4033
# Precio_Venta                    240.0
# Tendencia                           1
# Tipo_Liquidacion                Pesos
# Ultimo                          236.5
# Variacion                        2.83
# Vencimiento                       N/A
# Volumen_Nominal                     4
# Name: ALUC155.AG, dtype: object

# %%
data.index.values
# Out:
# array(['ALUC155.AG', 'ALUC170.AG', 'ALUC175.AG', 'ALUC190.AG',
#        'ALUC210.AG', 'ALUC215.AG', 'ALUC245.AG', 'ALUC255.AG',
#        'ALUC265.AG', 'ALUC300.AG', 'ALUC300.OC', 'ALUC310.AG',
#        'ALUC310.OC', 'ALUC320.AG', 'ALUC320.OC', 'ALUC350.AG',
#        'ALUC370.AG', 'ALUC370.OC', 'ALUC390.AG', 'ALUC390.OC',
#        'ALUC410.AG', 'ALUC410.DI', 'ALUC410.OC', 'ALUC430.AG',
#        'ALUC430.OC', 'ALUC450.AG', 'ALUC450.DI', 'ALUC450.OC',
#        'ALUV300.AG', 'ALUV310.AG', 'ALUV330.DI', 'ALUV330.OC',
#        'ALUV350.AG', 'ALUV350.DI', 'ALUV350.OC', 'ALUV370.AG',
#        'ALUV370.DI', 'ALUV370.OC', 'ALUV390.AG', 'ALUV390.DI',
#        'ALUV390.OC', 'ALUV410.AG', 'ALUV410.DI', 'ALUV410.OC',
#        'BBAC1020AG', 'BBAC1060AG', 'BBAC940.AG', 'BBAC980.AG',
#        'BBAV1020AG', 'BBAV1020OC', 'BBAV1060AG', 'BBAV1060OC',
#        'BBAV750.DI', 'BBAV750.OC', 'BBAV780.DI', 'BBAV780.OC',
#        'BBAV810.DI', 'BBAV810.OC', 'BBAV840.AG', 'BBAV840.DI',
#        'BBAV840.OC', 'BBAV870.AG', 'BBAV870.DI', 'BBAV870.OC',
#        'BBAV900.AG', 'BBAV900.DI', 'BBAV900.OC', 'BBAV940.AG',
#        'BBAV940.DI', 'BBAV940.OC', 'BBAV980.AG', 'BBAV980.DI',
#        'BBAV980.OC', 'BHIC26.0AG', 'BHIC26.0DI', 'BHIC26.0JL',
#        'BHIC26.0OC', 'BMAC11245G', 'BMAC1300AG', 'BMAC1350AG',
#        'BMAC1400AG', 'BMAC1450AG', 'BMAC1450OC', 'BMAC1500AG',
#        'BMAC1500OC', 'BMAC73775G', 'BMAC82454G', 'BMAV1000DI',
#        'BMAV1000OC', 'BMAV1050AG', 'BMAV1050DI', 'BMAV1050OC',
#        'BMAV1100AG', 'BMAV1100DI', 'BMAV1100OC', 'BMAV11245G',
#        'BMAV1150DI', 'BMAV1150OC', 'BMAV1200AG', 'BMAV1200DI',
#        'BMAV1200OC', 'BMAV1250AG', 'BMAV1250DI', 'BMAV1250OC',
#        'BMAV1300AG', 'BMAV1300DI', 'BMAV1300OC', 'BMAV1350AG',
#        'BMAV1350OC', 'BMAV1400AG', 'BMAV1400OC', 'BMAV1450AG',
#        'BMAV1450DI', 'BMAV1450OC', 'BMAV1500AG', 'BMAV82091O',
#        'BMAV890.DI', 'BMAV890.OC', 'BMAV910.DI', 'BMAV910.OC',
#        'BMAV950.AG', 'BMAV950.DI', 'BMAV950.OC', 'BMAV97454G',
#        'BOLC6.60AG', 'BYMC350.AG', 'BYMC360.AG', 'BYMC370.AG',
#        'BYMC380.AG', 'BYMC390.AG', 'BYMC390.OC', 'BYMC400.AG',
#        'BYMC400.OC', 'BYMC410.AG', 'BYMC410.OC', 'BYMC430.AG',
#        'BYMC430.DI', 'BYMC430.OC', 'BYMC450.AG', 'BYMC450.DI',
#        'BYMC450.OC', 'BYMC470.AG', 'BYMC470.DI', 'BYMC470.OC',
#        'BYMC490.AG', 'BYMC490.DI', 'BYMC490.OC', 'BYMV270.OC',
#        'BYMV320.AG', 'BYMV370.OC', 'BYMV390.DI', 'BYMV410.AG',
#        'CEPC300.AG', 'CEPC340.AG', 'CEPC360.AG', 'CEPC360.JL',
#        'CEPC380.AG', 'CEPC380.OC', 'CEPC400.AG', 'CEPC400.OC',
#        'CEPC420.AG', 'CEPC420.DI', 'CEPC420.OC', 'CEPC440.AG',
#        'CEPC440.DI', 'CEPC440.OC', 'CEPV250.OC', 'CEPV300.AG',
#        'CEPV300.OC', 'CEPV320.AG', 'CEPV320.OC', 'CEPV340.AG',
#        'CEPV360.AG', 'CEPV360.OC', 'CEPV380.AG', 'COMC27.0DI',
#        'COMC27.0OC', 'COMC27519G', 'COMC28519G', 'COMC29519G',
#        'COMC31519G', 'COMC32519G', 'COMC33519G', 'COMC35.0AG',
#        'COMC35.0OC', 'COMC35519O', 'COMC36.0AG', 'COMC37.0AG',
#        'COMC38.0AG', 'COMC39.0AG', 'COMC39.0DI', 'COMC39.0OC',
#        'COMC40.0AG', 'COMC40.0DI', 'COMC40.0OC', 'COMV24519G',
#        'COMV25.0OC', 'COMV33519G', 'COMV36.0AG', 'COMV38.0AG',
#        'COMV39.0AG', 'COMV40.0AG', 'CREC29657G', 'CREC390.AG',
#        'CREC410.AG', 'CREC430.AG', 'CREC450.AG', 'CREC450.OC',
#        'CREC470.AG', 'CREC470.DI', 'CREC470.OC', 'CREV24765G',
#        'CREV25744O', 'CREV300.DI', 'CREV300.OC', 'CREV310.DI',
#        'CREV310.OC', 'CREV320.DI', 'CREV320.OC', 'CREV32593G',
#        'CREV32593O', 'CREV330.AG', 'CREV330.DI', 'CREV330.OC',
#        'CREV340.DI', 'CREV340.OC', 'CREV350.DI', 'CREV370.AG',
#        'CREV370.DI', 'CREV370.OC', 'CREV390.AG', 'CREV390.DI',
#        'CREV390.OC', 'CREV410.AG', 'CREV410.OC', 'CREV430.AG',
#        'CREV430.OC', 'CREV450.AG', 'CREV470.AG', 'EDNC240.AG',
#        'EDNC250.OC', 'EDNC370.AG', 'EDNC390.AG', 'EDNC410.AG',
#        'EDNC410.DI', 'EDNC410.OC', 'EDNV240.OC', 'EDNV250.OC',
#        'EDNV350.AG', 'EDNV350.DI', 'EDNV350.OC', 'EDNV370.AG',
#        'EDNV370.DI', 'EDNV370.OC', 'EDNV390.AG', 'EDNV390.DI',
#        'EDNV390.OC', 'EDNV410.AG', 'EDNV410.DI', 'EDNV410.OC',
#        'EWZC8600AG', 'EWZC9000AG', 'EWZC9400AG', 'GFGC10415G',
#        'GFGC1050DI', 'GFGC1050OC', 'GFGC10915G', 'GFGC1100DI',
#        'GFGC1100OC', 'GFGC11415G', 'GFGC1150DI', 'GFGC1150OC',
#        'GFGC11915G', 'GFGC11915O', 'GFGC1200DI', 'GFGC12415G',
#        'GFGC1250DI', 'GFGC1250OC', 'GFGC12915G', 'GFGC1300DI',
#        'GFGC1300OC', 'GFGC1350AG', 'GFGC1350DI', 'GFGC1350OC',
#        'GFGC13915G', 'GFGC1400DI', 'GFGC1400OC', 'GFGC14415G',
#        'GFGC1450DI', 'GFGC1450OC', 'GFGC14915G', 'GFGC14915O',
#        'GFGC1500DI', 'GFGC34304G', 'GFGC34304O', 'GFGC37152G',
#        'GFGC39152G', 'GFGC41931G', 'GFGC43931G', 'GFGC44304O',
#        'GFGC45931G', 'GFGC47931G', 'GFGC49931G', 'GFGC51931G',
#        'GFGC55931G', 'GFGC56304G', 'GFGC57931G', 'GFGC580.OC',
#        'GFGC59931G', 'GFGC600.OC', 'GFGC60304O', 'GFGC640.OC',
#        'GFGC64304G', 'GFGC65931G', 'GFGC660.OC', 'GFGC66304G',
#        'GFGC680.OC', 'GFGC68304O', 'GFGC72304G', 'GFGC73152O',
#        'GFGC75304G', 'GFGC75304O', 'GFGC75931G', 'GFGC76152D',
#        'GFGC77931G', 'GFGC78304O', 'GFGC79152D', 'GFGC80304O',
#        'GFGC82152D', 'GFGC85304G', 'GFGC86152O', 'GFGC89304G',
#        'GFGC910.OC', 'GFGC93304G', 'GFGC950.OC', 'GFGC97304G',
#        'GFGC98152O', 'GFGV10415G', 'GFGV1050DI', 'GFGV14915G',
#        'GFGV14915O', 'GFGV34304G', 'GFGV37152G', 'GFGV41152G',
#        'GFGV41931G', 'GFGV43152G', 'GFGV43931G', 'GFGV44304O',
#        'GFGV45931G', 'GFGV460.DI', 'GFGV47931G', 'GFGV49931G',
#        'GFGV500.DI', 'GFGV51931G', 'GFGV55931G', 'GFGV56304G',
#        'GFGV57931G', 'GFGV59931G', 'GFGV60304O', 'GFGV620.DI',
#        'GFGV640.OC', 'GFGV64304G', 'GFGV65931G', 'GFGV660.DI',
#        'GFGV66304G', 'GFGV680.DI', 'GFGV68304O', 'GFGV72304G',
#        'GFGV740.DI', 'GFGV75304G', 'GFGV75304O', 'GFGV75931G',
#        'GFGV76152D', 'GFGV77931G', 'GFGV78304O', 'GFGV79152D',
#        'GFGV80304O', 'GFGV820.DI', 'GFGV82152D', 'GFGV85304G',
#        'GFGV86152O', 'GFGV89304G', 'GFGV910.DI', 'GFGV910.OC',
#        'GFGV93304G', 'GFGV950.OC', 'GFGV97304G', 'HARC480.AG',
#        'HARC500.AG', 'HARC520.AG', 'HARC540.AG', 'HARC540.OC',
#        'LOMC690.AG', 'LOMC710.AG', 'LOMC730.AG', 'LOMC750.AG',
#        'LOMC750.OC', 'LOMC770.AG', 'LOMC770.OC', 'LOMV60652G',
#        'LOMV60652O', 'LOMV64652G', 'LOMV650.DI', 'LOMV670.OC',
#        'LOMV690.AG', 'LOMV690.OC', 'LOMV710.AG', 'LOMV730.AG',
#        'LOMV730.OC', 'LOMV750.AG', 'LOMV770.AG', 'MELC10400G',
#        'MELC10800G', 'MELC11200G', 'MELC11600G', 'PAMC580.AG',
#        'PAMC720.AG', 'PAMC780.OC', 'PAMC800.AG', 'PAMC820.AG',
#        'PAMC820.OC', 'PAMC840.AG', 'PAMC860.AG', 'PAMC880.AG',
#        'PAMC900.AG', 'PAMC920.AG', 'PAMC920.OC', 'PAMV560.AG',
#        'PAMV600.OC', 'PAMV640.OC', 'PAMV700.OC', 'PAMV720.DI',
#        'PAMV720.OC', 'PAMV740.OC', 'PAMV800.DI', 'PAMV820.AG',
#        'PAMV820.DI', 'PAMV820.OC', 'PAMV840.AG', 'PAMV840.DI',
#        'PAMV840.OC', 'PAMV860.AG', 'PAMV860.OC', 'PAMV880.AG',
#        'PAMV880.DI', 'PAMV900.AG', 'PAMV920.AG', 'SAMC200.DI',
#        'SAMC200.JL', 'SAMC200.OC', 'SPYC10600O', 'SPYC11500G',
#        'SPYC11800G', 'SPYC12100G', 'SPYV10900G', 'SUPC290.AG',
#        'SUPC310.AG', 'SUPC330.AG', 'SUPC330.OC', 'SUPC350.AG',
#        'SUPC350.OC', 'SUPC370.AG', 'SUPC370.DI', 'SUPC370.OC',
#        'SUPV230.DI', 'SUPV230.OC', 'SUPV250.AG', 'SUPV250.DI',
#        'SUPV250.OC', 'SUPV270.AG', 'SUPV270.DI', 'SUPV270.OC',
#        'SUPV290.AG', 'SUPV290.DI', 'SUPV290.OC', 'SUPV310.AG',
#        'SUPV310.DI', 'SUPV310.OC', 'SUPV330.AG', 'SUPV330.DI',
#        'SUPV330.OC', 'SUPV350.AG', 'SUPV350.OC', 'TECC630.AG',
#        'TECC660.AG', 'TECC690.AG', 'TECC720.AG', 'TECC720.OC',
#        'TECV440.OC', 'TECV460.OC', 'TECV480.DI', 'TECV480.OC',
#        'TECV500.AG', 'TECV500.DI', 'TECV500.OC', 'TECV51758O',
#        'TECV520.AG', 'TECV520.DI', 'TECV520.OC', 'TECV540.AG',
#        'TECV540.DI', 'TECV570.AG', 'TECV570.DI', 'TECV570.OC',
#        'TECV600.AG', 'TECV600.DI', 'TECV600.OC', 'TECV630.AG',
#        'TECV630.OC', 'TECV660.AG', 'TECV660.OC', 'TECV690.AG',
#        'TECV720.AG', 'TGNC400.AG', 'TGNC580.OC', 'TGNC620.OC',
#        'TGNC660.AG', 'TGNC660.OC', 'TGNC680.AG', 'TGNC700.AG',
#        'TGNC700.OC', 'TGNC720.AG', 'TGNC720.OC', 'TGNC740.AG',
#        'TGNC740.JL', 'TGNC740.OC', 'TGNC760.AG', 'TGNC760.OC',
#        'TGNC780.AG', 'TGNC780.DI', 'TGNC780.OC', 'TGNV580.AG',
#        'TGNV580.OC', 'TGNV620.AG', 'TGNV620.OC', 'TGNV660.AG',
#        'TGNV660.OC', 'TGSC1280AG', 'TGSC1360AG', 'TGSC1400AG',
#        'TGSC1440AG', 'TGSV1200DI', 'TGSV1200OC', 'TGSV1240OC',
#        'TGSV1280AG', 'TGSV1320AG', 'TGSV1320DI', 'TGSV1320OC',
#        'TGSV1360AG', 'TGSV1360DI', 'TGSV1360OC', 'TGSV1400AG',
#        'TGSV1400DI', 'TGSV1400OC', 'TGSV1440AG', 'TGSV1440OC',
#        'TRAC300.AG', 'TRAC340.AG', 'TRAC360.AG', 'TRAC360.OC',
#        'TRAV280.OC', 'TRAV310.DI', 'TRAV310.OC', 'TRAV320.AG',
#        'TRAV320.DI', 'TRAV320.OC', 'TRAV330.AG', 'TRAV330.DI',
#        'TRAV330.OC', 'TRAV340.AG', 'TRAV340.DI', 'TRAV340.OC',
#        'TRAV350.AG', 'TRAV350.DI', 'TRAV350.OC', 'TRAV360.AG',
#        'TRAV360.DI', 'TRAV360.OC', 'TSLC10000G', 'TSLC9400AG',
#        'TSLC9600AG', 'TSLC9800AG', 'TXAC19003G', 'TXAC20003G',
#        'TXAC25003G', 'TXAC27003G', 'TXAC390.AG', 'TXAC400.AG',
#        'TXAC420.AG', 'TXAC440.AG', 'TXAC440.OC', 'TXAC460.AG',
#        'TXAC460.OC', 'TXAC480.AG', 'TXAC480.OC', 'TXAC500.AG',
#        'TXAC500.DI', 'TXAC500.OC', 'TXAC520.AG', 'TXAC520.DI',
#        'TXAC520.OC', 'TXAC540.AG', 'TXAC540.DI', 'TXAC540.OC',
#        'TXAC560.AG', 'TXAC560.DI', 'TXAC560.OC', 'TXAV27003G',
#        'TXAV290.AG', 'TXAV290.OC', 'TXAV300.OC', 'TXAV30003O',
#        'TXAV340.AG', 'TXAV380.AG', 'TXAV380.DI', 'TXAV390.AG',
#        'TXAV400.AG', 'TXAV420.AG', 'TXAV440.OC', 'TXAV460.AG',
#        'VSTC13000D', 'VSTC13000G', 'VSTC13000O', 'VSTC13300G',
#        'VSTC13600G', 'VSTC13900G', 'YPFC10000D', 'YPFC10000G',
#        'YPFC10600D', 'YPFC3700AG', 'YPFC3800AG', 'YPFC3900AG',
#        'YPFC4000AG', 'YPFC4100AG', 'YPFC4500AG', 'YPFC5000AG',
#        'YPFC5700AG', 'YPFC5900AG', 'YPFC6100AG', 'YPFC6300AG',
#        'YPFC6300OC', 'YPFC6500AG', 'YPFC6500OC', 'YPFC6700AG',
#        'YPFC6700DI', 'YPFC6700OC', 'YPFC7000AG', 'YPFC7000OC',
#        'YPFC7300AG', 'YPFC7300OC', 'YPFC7600AG', 'YPFC7600OC',
#        'YPFC7900AG', 'YPFC7900DI', 'YPFC8200AG', 'YPFC8200OC',
#        'YPFC8500AG', 'YPFC8500OC', 'YPFC8800AG', 'YPFC9100AG',
#        'YPFC9100DI', 'YPFC9100OC', 'YPFC9400AG', 'YPFC9400DI',
#        'YPFC9400OC', 'YPFC9700AG', 'YPFV3000AG', 'YPFV3500AG',
#        'YPFV3900AG', 'YPFV4300AG', 'YPFV4500AG', 'YPFV4500DI',
#        'YPFV4900AG', 'YPFV5000AG', 'YPFV5000DI', 'YPFV5200AG',
#        'YPFV5200DI', 'YPFV5700AG', 'YPFV5700DI', 'YPFV6100DI',
#        'YPFV6300AG', 'YPFV6500DI', 'YPFV6500OC', 'YPFV6700AG',
#        'YPFV6700DI', 'YPFV7000AG', 'YPFV7000DI', 'YPFV7000OC',
#        'YPFV7300AG', 'YPFV7300DI', 'YPFV7300OC', 'YPFV7600AG',
#        'YPFV7900AG', 'YPFV8200AG'], dtype=object)

# %% [markdown]
# # Yapa panel Opciones plus

# %%
# Descarga de todos los paneles de subyacentes con opciones (lider, general y cedears)
params = {"action":"get_panel", "panel_id":"0"}
data = pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')
cierres = data['Ultimo'].to_dict()

params = {"action":"get_panel", "panel_id":"2"}
data = pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')
galpones = data['Ultimo'].to_dict()
cierres.update(galpones)

params = {"action":"get_panel", "panel_id":"5"}
data = pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')
cedears = data['Ultimo'].to_dict()
cierres.update(cedears)

# %%
# Listado de equivalencias de ticker de accion y subyecente de opcion
equiv = {"AGR":"AGRO","ALU":"ALUA","PBR":"APBR","AUS":"AUSO","BHI":"BHIP","BMA":"BMA","BOL":"BOLT","BPA":"BPAT",
         "BRI":"BRIO","BYM":"BYMA","CAD":"CADO","CPU":"CAPU","CAP":"CAPX","CAR":"CARC","CEC":"CECO2","CEL":"CELU",
         "CEP":"CEPU","CGP":"CGPA2","COL":"COLO","COM":"COME","CRE":"CRES","CTO":"CTIO","DGC":"DGCU2","DYC":"DYCA",
         "EDN":"EDN","TXA":"TXAR","BBA":"BBAR","FER":"FERR","FIP":"FIPL","GAR":"GARO","GBN":"GBAN","GCL":"GCLA",
         "GFG":"GGAL","GRI":"GRIM","HAV":"HAVA","IND":"INDU","INT":"INTR","INV":"INVJ","IRC":"IRCP","IRS":"IRSA",
         "HAR":"HARG","LED":"LEDE","LON":"LONG","MET":"METR","MIR":"MIRG","MOL":"MOLI","MOR":"MORI","OES":"OEST",
         "OVO":"OVOP","PAM":"PAMP","PAT":"PATA","PES":"PESA","PET":"PETR","POL":"POLL","REP":"REP","RIG":"RIGO",
         "ROS":"ROSE","SAM":"SAMI","SEM":"SEMI","STD":"STD","SUP":"SUPV","TEC":"TECO2","TEF":"TEF","TGL":"TGLT",
         "TGN":"TGNO4","TGS":"TGSU2","TRA":"TRAN","TS.":"TS","YPF":"YPFD","GVA":"VALO","BYM":"BYMA","CVH":"CVH",
         "PGR":"PGR", "APL":"AAPL","LOM":"LOMA", "MEL":"MELI", "PBR":"PBR", "TEN":"TEN", "TSL":"TSLA",
         "SPY":"SPY", "VST":"VIST","EWZ":"EWZ" }

# %%
import datetime

# Funcion para obtener parametros desde el ticker de la opcion
def getOptData(ticker):
    vencimientos_2c = ["EN","FE","MA","AB", "MY", "JU","JL","AG", "SE", "OC", "NO", "DI"];
    vencimientos_1c = ["E","F","M","A","Y","J","L","G","S","O","N","D"];

    ticker_opc = ticker[:3]
    ticker_suby = equiv[ticker_opc]
    s = cierres[ticker_suby]

    tipo = 'Call' if ticker[3]=="C" else 'Put'

    if  ticker[-2].isnumeric():
        mes = ticker[-1:]
        vto_mes = vencimientos_1c.index(mes) +1
        strike = float(ticker[4:-1])
            # si tiene 4 digitos MIRC16078J es /10**1 >> k=1607.8
            # si tiene 3 digitos GFGC13398G es /10**2 >> k=133.98
            # si tiene 2 digitos GFGV85983J es /10**3 >> k=85.983
            # Ahora como fucking me doy cuenta si esta autodefinido? tengo que tenes un s "base"

        p_otm = strike/s -1 if tipo=='Call' else 1-strike/s
        if abs(p_otm) > 1:
            strike /= 10
            p_otm = strike/s -1 if tipo=='Call' else 1-strike/s
            if abs(p_otm) > 1:
                strike /= 10
                p_otm = strike/s -1 if tipo=='Call' else 1-strike/s
                if abs(p_otm) > 1:
                    strike /= 10
                    p_otm = strike/s -1 if tipo=='Call' else 1-strike/s

    else:
        mes = ticker[-2:]
        vto_mes = vencimientos_2c.index(mes) +1
        strike = float(ticker[4:-2])
        p_otm = strike/s -1 if tipo=='Call' else 1-strike/s

    hoy = datetime.date.today()

    vto_primer_dia_mes = datetime.date(hoy.year, vto_mes,1).isoweekday()
    # primer dia = 1 (lunes) > vto cae el 19
    # primer dia = 2 (martes) > vto cae el 18
    # primer dia = 3 (miercoles) > vto cae el 17
    # primer dia = 4 (jueves) > vto cae el 16
    # primer dia = 5 (viernes) > vto cae el 15
    # primer dia = 6 (sabado) > vto cae el 21
    # primer dia = 7 (domingo) > vto cae el 20
    vto_dia = 7-vto_primer_dia_mes + 13 if vto_primer_dia_mes <= 5 else 7-vto_primer_dia_mes + 20

    vto_año = hoy.year
    vto = datetime.date(vto_año, vto_mes, vto_dia)
    ttm_dias = (vto - hoy).days

    # Arreglo por si estamos ponele en diciembre y leo opciones de enero, febrero etc..
    vto_año = vto_año if ttm_dias > 0 else vto_año+1
    vto = datetime.date(vto_año, vto_mes, vto_dia)
    ttm_dias = (vto - hoy).days
    ttm = ttm_dias / 365

    money = 'ITM' if p_otm < 0 else 'OTM'

    r = {'ticker' : ticker, 'ticker_opc': ticker_opc, 'ticker_suby': ticker_suby,
         'tipo':tipo,  'strike':strike,  's':s, 'p_otm':p_otm, 'vto':vto,
         'ttm_dias':ttm_dias, 'money':money, 'ttm':ttm}
    return r

# %%
# Probamos como anda la extraccion de params desde el ticker
data_opc = getOptData("GFGC77931G")
data_opc
# Out:
# {'ticker': 'GFGC77931G',
#  'ticker_opc': 'GFG',
#  'ticker_suby': 'GGAL',
#  'tipo': 'Call',
#  'strike': 779.3100000000001,
#  's': 834.8,
#  'p_otm': -0.0664710110206036,
#  'vto': datetime.date(2023, 8, 18),
#  'ttm_dias': 38,
#  'money': 'ITM',
#  'ttm': 0.10410958904109589}

# %%
# Bajo data de opciones
params = {"action":"get_panel", "panel_id":"4"}
opciones = pd.DataFrame(scrapByma(params)['Cotizaciones']).set_index('Simbolo')

# %%
opciones_tickers = opciones.index.values
opciones_full = []

for opcion in opciones_tickers:
    try:
        data_opc = getOptData(opcion)
        data_opc['ultimo'] = opciones.loc[opcion,'Ultimo']
        data_opc['bid'] = opciones.loc[opcion,'Precio_Compra']
        data_opc['ask'] = opciones.loc[opcion,'Precio_Venta']
        data_opc['monto'] = opciones.loc[opcion,'Monto_Operado_Pesos']
        opciones_full.append(data_opc)
    except:
        print(f'NO puedo calcular {opcion}')

# %%
pd.options.display.max_columns = None
opc_df = pd.DataFrame(opciones_full)
opc_df
# Out:
#          ticker ticker_opc ticker_suby  tipo  strike        s     p_otm  \
# 0    ALUC155.AG        ALU        ALUA  Call   155.0   378.00 -0.589947
# 1    ALUC170.AG        ALU        ALUA  Call   170.0   378.00 -0.550265
# 2    ALUC175.AG        ALU        ALUA  Call   175.0   378.00 -0.537037
# 3    ALUC190.AG        ALU        ALUA  Call   190.0   378.00 -0.497354
# 4    ALUC210.AG        ALU        ALUA  Call   210.0   378.00 -0.444444
# ..          ...        ...         ...   ...     ...      ...       ...
# 689  YPFV7300DI        YPF        YPFD   Put  7300.0  7513.95  0.028474
# 690  YPFV7300OC        YPF        YPFD   Put  7300.0  7513.95  0.028474
# 691  YPFV7600AG        YPF        YPFD   Put  7600.0  7513.95 -0.011452
# 692  YPFV7900AG        YPF        YPFD   Put  7900.0  7513.95 -0.051378
# 693  YPFV8200AG        YPF        YPFD   Put  8200.0  7513.95 -0.091304
#
#             vto  ttm_dias money       ttm  ultimo     bid     ask     monto
# 0    2023-08-18        38   ITM  0.104110   236.5    2.00  240.00     94542
# 1    2023-08-18        38   ITM  0.104110   228.0  220.76  228.00  12725978
# 2    2023-08-18        38   ITM  0.104110     0.0  216.27  224.02         0
# 3    2023-08-18        38   ITM  0.104110     0.0  202.81  218.00         0
# 4    2023-08-18        38   ITM  0.104110     0.0  184.86  193.19         0
# ..          ...       ...   ...       ...     ...     ...     ...       ...
# 689  2023-12-15       157   OTM  0.430137     0.0   87.50    0.00         0
# 690  2023-10-20       101   OTM  0.276712     0.0  150.00    0.00         0
# 691  2023-08-18        38   ITM  0.104110   329.5  270.00  320.00    331050
# 692  2023-08-18        38   ITM  0.104110     0.0    0.00  750.00         0
# 693  2023-08-18        38   ITM  0.104110     0.0  100.00  900.00         0
#
# [694 rows x 15 columns]

# %%
opc_df.loc[opc_df.ticker_suby=="GGAL"]
# Out:
#          ticker ticker_opc ticker_suby  tipo   strike      s     p_otm  \
# 263  GFGC10415G        GFG        GGAL  Call  1041.50  834.8  0.247604
# 264  GFGC1050DI        GFG        GGAL  Call  1050.00  834.8  0.257786
# 265  GFGC1050OC        GFG        GGAL  Call  1050.00  834.8  0.257786
# 266  GFGC10915G        GFG        GGAL  Call  1091.50  834.8  0.307499
# 267  GFGC1100DI        GFG        GGAL  Call  1100.00  834.8  0.317681
# ..          ...        ...         ...   ...      ...    ...       ...
# 382  GFGV910.DI        GFG        GGAL   Put   910.00  834.8 -0.090081
# 383  GFGV910.OC        GFG        GGAL   Put   910.00  834.8 -0.090081
# 384  GFGV93304G        GFG        GGAL   Put   933.04  834.8 -0.117681
# 385  GFGV950.OC        GFG        GGAL   Put   950.00  834.8 -0.137997
# 386  GFGV97304G        GFG        GGAL   Put   973.04  834.8 -0.165597
#
#             vto  ttm_dias money       ttm   ultimo      bid      ask     monto
# 263  2023-08-18        38   OTM  0.104110   37.500   37.080   38.700  25589173
# 264  2023-12-15       157   OTM  0.430137    0.000    0.989  210.000         0
# 265  2023-10-20       101   OTM  0.276712    0.000   67.970  154.790         0
# 266  2023-08-18        38   OTM  0.104110   30.899   15.000   30.899  30750952
# 267  2023-12-15       157   OTM  0.430137    0.000   89.500  175.000         0
# ..          ...       ...   ...       ...      ...      ...      ...       ...
# 382  2023-12-15       157   ITM  0.430137    0.000    1.690    0.000         0
# 383  2023-10-20       101   ITM  0.276712    0.000   54.000    0.000         0
# 384  2023-08-18        38   ITM  0.104110  101.000   98.501  103.999   3333372
# 385  2023-10-20       101   ITM  0.276712    0.000    0.990    0.000         0
# 386  2023-08-18        38   ITM  0.104110  145.000  129.001  139.950   1206400
#
# [124 rows x 15 columns]
