# %% [markdown]
# # Lectura de data (CSV)

# %%
import pandas as pd

# %%
sp500_monthly = pd.read_csv('https://datahub.io/core/s-and-p-500/r/data.csv')
sp500_monthly
# Out:
#             Date    SP500  Dividend  Earnings  Consumer Price Index  \
# 0     1871-01-01     4.44      0.26      0.40                 12.46
# 1     1871-02-01     4.50      0.26      0.40                 12.84
# 2     1871-03-01     4.61      0.26      0.40                 13.03
# 3     1871-04-01     4.74      0.26      0.40                 12.56
# 4     1871-05-01     4.86      0.26      0.40                 12.27
# ...          ...      ...       ...       ...                   ...
# 1763  2017-12-01  2664.34     48.93    109.88                246.52
# 1764  2018-01-01  2789.80     49.29       NaN                247.87
# 1765  2018-02-01  2705.16     49.64       NaN                248.99
# 1766  2018-03-01  2702.77     50.00       NaN                249.55
# 1767  2018-04-01  2642.19       NaN       NaN                249.84
#
#       Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10
# 0                   5.32       89.00           5.21           8.02    NaN
# 1                   5.32       87.53           5.06           7.78    NaN
# 2                   5.33       88.36           4.98           7.67    NaN
# 3                   5.33       94.29           5.17           7.96    NaN
# 4                   5.33       98.93           5.29           8.14    NaN
# ...                  ...         ...            ...            ...    ...
# 1763                2.40     2700.13          49.59         111.36  32.09
# 1764                2.58     2811.96          49.68            NaN  33.31
# 1765                2.86     2714.34          49.81            NaN  32.12
# 1766                2.84     2705.82          50.06            NaN  31.99
# 1767                2.80     2642.19            NaN            NaN  31.19
#
# [1768 rows x 10 columns]

# %% [markdown]
# # Lectura de data desde tabla WEB

# %%
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

# %%
sp500_tickers[0]
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# # Lectura de data desde ZIP

# %%
import requests
import io
from zipfile import ZipFile

url = "https://github.com/gauss314/ucema/raw/main/opciones_hist_2020_Q1.zip"
r = requests.get(url)
zip_file = ZipFile(io.BytesIO(r.content))

# Extrae el nombre del archivo CSV dentro del ZIP
csv_file = zip_file.namelist()[0]

# Lee el archivo CSV con pandas
df = pd.read_csv(zip_file.open(csv_file))
df
# Out:
#              id  sigma10  sigma20  sigma40  sigma250  vi_ultima  vi_compra  \
# 0        273811       21       35       55        51      55.98        NaN
# 1        273812       21       35       55        51      32.32        NaN
# 2        273813       21       35       55        51      46.22        NaN
# 3        273814       21       35       55        51      56.67        NaN
# 4        273815       21       35       55        51      43.33        NaN
# ...         ...      ...      ...      ...       ...        ...        ...
# 827628  1101439      236      198      143        74      97.25        NaN
# 827629  1101440      236      198      143        74     129.13        NaN
# 827630  1101441      236      198      143        74     132.78        NaN
# 827631  1101442      236      198      143        74     132.84        NaN
# 827632  1101443      236      198      143        74     148.21        NaN
#
#         vi_venta  strike     simbolo  ...  subyacente  subyacente_precio  \
# 0            NaN   31.00  ALUC31.0FE  ...        ALUA               32.4
# 1            NaN   33.00  ALUC33.0AB  ...        ALUA               32.4
# 2            NaN   33.00  ALUC33.0FE  ...        ALUA               32.4
# 3            NaN   25.37  ALUV25.37F  ...        ALUA               32.4
# 4            NaN   33.00  ALUV33.0FE  ...        ALUA               32.4
# ...          ...     ...         ...  ...         ...                ...
# 827628       NaN  960.00  YPFC960.JU  ...        YPFD              345.5
# 827629       NaN  300.00  YPFV300.AB  ...        YPFD              345.5
# 827630       NaN  400.00  YPFV400.AB  ...        YPFD              345.5
# 827631       NaN  420.00  YPFV420.AB  ...        YPFD              345.5
# 827632       NaN  580.00  YPFV580.AG  ...        YPFD              345.5
#
#         tipo    tiempo  ruedas_faltantes_opex  black_scholes  otm  \
# 0       Call  0.136986                     36          4.343   -4
# 1       Call  0.290411                     76          5.385    2
# 2       Call  0.136986                     36          3.227    2
# 3        Put  0.136986                     36          0.182   22
# 4        Put  0.136986                     36          2.054   -2
# ...      ...       ...                    ...            ...  ...
# 827628  Call  0.216438                     57         12.090  178
# 827629   Put  0.043836                     12         18.334   13
# 827630   Put  0.043836                     12         72.811  -16
# 827631   Put  0.043836                     12         87.610  -22
# 827632   Put  0.389041                    102        245.541  -68
#
#         valor_intrinseco valor_extrinseco  fecha_negociado
# 0                    1.4            2.966       2019-12-27
# 1                    NaN            4.000       2019-12-30
# 2                    NaN            2.805       2019-12-30
# 3                    NaN            0.200       2019-12-30
# 4                    0.6            0.900       2019-12-30
# ...                  ...              ...              ...
# 827628               NaN            1.553       2020-03-30
# 827629               NaN           15.167       2020-03-30
# 827630              54.5           15.500       2020-03-30
# 827631              74.5           10.500       2020-03-26
# 827632             234.5           15.500       2020-03-30
#
# [827633 rows x 28 columns]

# %% [markdown]
# # Metodos loc e iloc

# %% [markdown]
# ## Diferencia entre loc e iloc

# %% [markdown]
# * loc se refiere a "nombres", "etiquetas"
# * iloc se refiere a "indices", "ubicaciones"

# %%
acciones_list = [{'Ticker':'GGAL','Nombre':'Banco Galicia','Pais':'Argentina','Rubro':'Bancos'},
                 {'Ticker':'PAMP','Nombre':'Pampa Energía','Pais':'Argentina','Rubro':'Energéticas'},
                 {'Ticker':'MSFT','Nombre':'Microsoft','Pais':'USA','Rubro':'Tecnológicas'},
                 {'Ticker':'BABA','Nombre':'Alibaba','Pais':'China','Rubro':'Consumo'}]

acciones = pd.DataFrame(acciones_list).set_index('Ticker')
acciones
# Out:
#                Nombre       Pais         Rubro
# Ticker
# GGAL    Banco Galicia  Argentina        Bancos
# PAMP    Pampa Energía  Argentina   Energéticas
# MSFT        Microsoft        USA  Tecnológicas
# BABA          Alibaba      China       Consumo

# %% [markdown]
# #### Filtros solo de filas

# %%
acciones.iloc[0:2]
# Out:
#                Nombre       Pais        Rubro
# Ticker
# GGAL    Banco Galicia  Argentina       Bancos
# PAMP    Pampa Energía  Argentina  Energéticas

# %%
acciones.loc['GGAL':'PAMP']
# Out:
#                Nombre       Pais        Rubro
# Ticker
# GGAL    Banco Galicia  Argentina       Bancos
# PAMP    Pampa Energía  Argentina  Energéticas

# %% [markdown]
# #### Filtros de filas y columnas

# %%
# Ej. Las ultimas 2 filas, la ultima columna
acciones.iloc[-2:, -1]
# Out:
# Ticker
# MSFT    Tecnológicas
# BABA         Consumo
# Name: Rubro, dtype: object

# %%
# Ej. Desde GGAL hasta PAMP, las columnas, Nombre y Rubro.
acciones.loc['GGAL':'PAMP', ['Nombre','Rubro']]
# Out:
#                Nombre        Rubro
# Ticker
# GGAL    Banco Galicia       Bancos
# PAMP    Pampa Energía  Energéticas

# %%
acciones_list = [{'Ticker':'GGAL','Nombre':'Banco Galicia','Pais':'Argentina','Rubro':'Bancos'},
                 {'Ticker':'PAMP','Nombre':'Pampa Energía','Pais':'Argentina','Rubro':'Energéticas'},
                 {'Ticker':'MSFT','Nombre':'Microsoft','Pais':'USA','Rubro':'Tecnológicas'},
                 {'Ticker':'BABA','Nombre':'Alibaba','Pais':'China','Rubro':'Consumo'}]

acciones = pd.DataFrame(acciones_list)
acciones
# Out:
#   Ticker         Nombre       Pais         Rubro
# 0   GGAL  Banco Galicia  Argentina        Bancos
# 1   PAMP  Pampa Energía  Argentina   Energéticas
# 2   MSFT      Microsoft        USA  Tecnológicas
# 3   BABA        Alibaba      China       Consumo

# %%
acciones.iloc[:2] # Aca selecciono hasta el indice 2
# Out:
#   Ticker         Nombre       Pais        Rubro
# 0   GGAL  Banco Galicia  Argentina       Bancos
# 1   PAMP  Pampa Energía  Argentina  Energéticas

# %%
# las coincidencias de etiquetas las toma como strings exactos, o sea inclusive
acciones.loc[:2]  # Aca selecciono hasta la etiqueta 2
# Out:
#   Ticker         Nombre       Pais         Rubro
# 0   GGAL  Banco Galicia  Argentina        Bancos
# 1   PAMP  Pampa Energía  Argentina   Energéticas
# 2   MSFT      Microsoft        USA  Tecnológicas

# %% [markdown]
# # Set index

# %%
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# %%
sp500_tickers
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %%
sp500_tickers.set_index('Symbol')
# Out:
#                     Security             GICS Sector  \
# Symbol
# MMM                       3M             Industrials
# AOS              A. O. Smith             Industrials
# ABT                   Abbott             Health Care
# ABBV                  AbbVie             Health Care
# ACN                Accenture  Information Technology
# ...                      ...                     ...
# YUM              Yum! Brands  Consumer Discretionary
# ZBRA      Zebra Technologies  Information Technology
# ZBH            Zimmer Biomet             Health Care
# ZION    Zions Bancorporation              Financials
# ZTS                   Zoetis             Health Care
#
#                          GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates    Saint Paul, Minnesota
# AOS                      Building Products     Milwaukee, Wisconsin
# ABT                  Health Care Equipment  North Chicago, Illinois
# ABBV                       Pharmaceuticals  North Chicago, Illinois
# ACN         IT Consulting & Other Services          Dublin, Ireland
# ...                                    ...                      ...
# YUM                            Restaurants     Louisville, Kentucky
# ZBRA    Electronic Equipment & Instruments   Lincolnshire, Illinois
# ZBH                  Health Care Equipment          Warsaw, Indiana
# ZION                        Regional Banks     Salt Lake City, Utah
# ZTS                        Pharmaceuticals   Parsippany, New Jersey
#
#         Date added      CIK      Founded
# Symbol
# MMM     1957-03-04    66740         1902
# AOS     2017-07-26    91142         1916
# ABT     1957-03-04     1800         1888
# ABBV    2012-12-31  1551152  2013 (1888)
# ACN     2011-07-06  1467373         1989
# ...            ...      ...          ...
# YUM     1997-10-06  1041061         1997
# ZBRA    2019-12-23   877212         1969
# ZBH     2001-08-07  1136869         1927
# ZION    2001-06-22   109380         1873
# ZTS     2013-06-21  1555280         1952
#
# [503 rows x 7 columns]

# %%
sp500_tickers # Si no se hace la asignacion no queda guardado el seteo
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# # Creacion de nuevas columnas

# %% [markdown]
# ## Ejercicio
# Bajar los datos de AAPL
#
# Crear una nueva columna con el color de la vela diaria
# * Verde si Close > Open
# * Rojo si Close < Open
# * Doji, si Close = Open

# %%
import yfinance as yf

data = yf.download('AAPL', start='2001-01-01', auto_adjust=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume
# Date
# 2001-01-02    0.225766    0.231457    0.221023    0.225766  452312000
# 2001-01-03    0.220075    0.253275    0.219126    0.248533  817073600
# 2001-01-04    0.275330    0.280785    0.255172    0.258967  739396000
# 2001-01-05    0.257070    0.263710    0.243789    0.248533  412356000
# 2001-01-08    0.257069    0.257781    0.241892    0.251378  373699200
# ...                ...         ...         ...         ...        ...
# 2023-05-23  173.130005  173.380005  171.279999  171.559998   50747300
# 2023-05-24  171.089996  172.419998  170.520004  171.839996   45143500
# 2023-05-25  172.410004  173.899994  171.690002  172.990005   56058300
# 2023-05-26  173.320007  175.770004  173.110001  175.429993   54794100
# 2023-05-30  176.960007  178.990005  176.570007  177.289505   26403807
#
# [5637 rows x 5 columns]

# %% [markdown]
# ## Modo iterativo

# %%
# %%time

colors = []
for i in range(len(data)):

    if data.iloc[i]['Close'] > data.iloc[i]['Open']:
        colors.append("verde")

    elif data.iloc[i]['Close'] == data.iloc[i]['Open']:
        colors.append("doji")

    else:
        colors.append("roja")


data['Color'] = colors
data
# Out:
# CPU times: user 1.3 s, sys: 258 µs, total: 1.3 s
# Wall time: 1.3 s
#                   Open        High         Low       Close     Volume  Color
# Date
# 2001-01-02    0.225766    0.231457    0.221023    0.225766  452312000   roja
# 2001-01-03    0.220075    0.253275    0.219126    0.248533  817073600  verde
# 2001-01-04    0.275330    0.280785    0.255172    0.258967  739396000   roja
# 2001-01-05    0.257070    0.263710    0.243789    0.248533  412356000   roja
# 2001-01-08    0.257069    0.257781    0.241892    0.251378  373699200   roja
# ...                ...         ...         ...         ...        ...    ...
# 2023-05-23  173.130005  173.380005  171.279999  171.559998   50747300   roja
# 2023-05-24  171.089996  172.419998  170.520004  171.839996   45143500  verde
# 2023-05-25  172.410004  173.899994  171.690002  172.990005   56058300  verde
# 2023-05-26  173.320007  175.770004  173.110001  175.429993   54794100  verde
# 2023-05-30  176.960007  178.990005  176.570007  177.289505   26403807  verde
#
# [5637 rows x 6 columns]

# %% [markdown]
# ## Modo matricial

# %%
# %%time
mask_verde = data['Close'] > data['Open']
mask_roja = data['Close'] < data['Open']
mask_doji = data['Close'] == data['Open']

data.loc[mask_verde, 'Color'] = 'verde'
data.loc[mask_roja, 'Color'] = 'roja'
data.loc[mask_doji, 'Color'] = 'doji'
data
# Out:
# CPU times: user 3.28 ms, sys: 0 ns, total: 3.28 ms
# Wall time: 3.32 ms
#                   Open        High         Low       Close     Volume  Color
# Date
# 2001-01-02    0.225766    0.231457    0.221023    0.225766  452312000   roja
# 2001-01-03    0.220075    0.253275    0.219126    0.248533  817073600  verde
# 2001-01-04    0.275330    0.280785    0.255172    0.258967  739396000   roja
# 2001-01-05    0.257070    0.263710    0.243789    0.248533  412356000   roja
# 2001-01-08    0.257069    0.257781    0.241892    0.251378  373699200   roja
# ...                ...         ...         ...         ...        ...    ...
# 2023-05-23  173.130005  173.380005  171.279999  171.559998   50747300   roja
# 2023-05-24  171.089996  172.419998  170.520004  171.839996   45143500  verde
# 2023-05-25  172.410004  173.899994  171.690002  172.990005   56058300  verde
# 2023-05-26  173.320007  175.770004  173.110001  175.429993   54794100  verde
# 2023-05-30  176.960007  178.990005  176.570007  177.289505   26403807  verde
#
# [5637 rows x 6 columns]

# %% [markdown]
# # Orden

# %%
data.sort_values('Volume', ascending=False)
# Out:
#                   Open        High         Low       Close      Volume  Color
# Date
# 2008-01-23    4.134062    4.249714    3.828993    4.221484  3372969600  verde
# 2007-01-09    2.624198    2.822416    2.584736    2.809971  3349298400  verde
# 2005-01-13    1.118737    1.129514    1.058331    1.059393  3164716800   roja
# 2007-01-10    2.876145    2.968728    2.836683    2.944444  2952880000  verde
# 2004-10-14    0.655518    0.694373    0.645804    0.682686  2768427200  verde
# ...                ...         ...         ...         ...         ...    ...
# 2021-11-11  147.670434  148.136351  146.401501  146.589859    41000000   roja
# 2002-12-24    0.219164    0.219619    0.217039    0.217950    39340000   roja
# 2023-05-15  173.160004  173.210007  171.470001  172.070007    37266700   roja
# 2022-11-25  147.879363  148.447715  146.692816  147.679947    35195900   roja
# 2023-05-30  176.960007  178.990005  176.570007  177.289505    26403807  verde
#
# [5637 rows x 6 columns]

# %% [markdown]
# # Agrupamiento

# %%
data.groupby('Color').size()
# Out:
# Color
# doji       12
# roja     2714
# verde    2911
# dtype: int64

# %%
data.groupby('Color').mean()
# Out:
#             Open       High        Low      Close        Volume
# Color
# doji   23.118757  23.326523  22.923686  23.118757  3.399165e+08
# roja   31.354990  31.533710  30.818287  30.993857  4.165958e+08
# verde  33.052540  33.591709  32.873386  33.432929  3.947850e+08

# %% [markdown]
# # Ejercicio aplicacion
#
# Usando el ejercicio anterior, calcular el % de las ruedas con velas rojas del top 200 de mayor volumen historico
#
# Calcular luego el % de Verdes, Rojas y Dojis de todo el historico

# %%
data.sort_values('Volume', ascending=False).head(200).groupby('Color').size()
# Out:
# Color
# doji       1
# roja     104
# verde     95
# dtype: int64

# %% [markdown]
# # Ejercicio (probar con chatGPT)
#
# descargar los precios historicos de MSFT desde 2010 y calcular la volatilidad intradiaria segun el color de la vela, tomar los dias neutros como vela verde

# %% [markdown]
# # Guardado de dataframes a excel o csv

# %%
data = yf.download('GOOG')

mask_verde = data['Close'] > data['Open']
mask_roja = data['Close'] < data['Open']
mask_doji = data['Close'] == data['Open']

data.loc[mask_verde, 'Color'] = 'verde'
data.loc[mask_roja, 'Color'] = 'roja'
data.loc[mask_doji, 'Color'] = 'doji'

data.to_excel('data_goog_excel.xlsx')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.to_csv('data_goog_excel.csv')

# %% [markdown]
# # Bloque 2

# %% [markdown]
# # Ranks

# %%
import yfinance as yf
data = yf.download('GGAL')
data['variacion'] = data['Adj Close'].pct_change()*100
data = data.dropna()
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume  variacion
# Date
# 2000-07-26  17.2500  17.5625  17.1875  17.5000  15.130225   28900   0.000000
# 2000-07-27  17.5000  17.6250  17.3750  17.5000  15.130225   61200   0.000000
# 2000-07-28  17.5625  17.5625  17.1250  17.3750  15.022151  146100  -0.714293
# 2000-07-31  17.5000  17.6875  16.8750  17.6875  15.292333  178400   1.798555
# 2000-08-01  17.5625  18.4375  17.2500  17.5000  15.130225   87400  -1.060057
# ...             ...      ...      ...      ...        ...     ...        ...
# 2023-05-23  11.2700  11.8800  11.2700  11.4600  11.460000  439900   0.791558
# 2023-05-24  11.4500  11.9000  11.2100  11.7600  11.760000  671400   2.617803
# 2023-05-25  11.7000  11.8500  11.4400  11.6600  11.660000  225200  -0.850343
# 2023-05-26  11.6300  11.8800  11.4500  11.6800  11.680000  252200   0.171531
# 2023-05-30  11.6000  11.7200  11.3650  11.7100  11.710000  130390   0.256847
#
# [5747 rows x 7 columns]

# %%
df = data.copy()
df['variacion_ranking'] = data.variacion.rank()
df
# Out:
#                Open     High      Low    Close  Adj Close  Volume  variacion  \
# Date
# 2000-07-26  17.2500  17.5625  17.1875  17.5000  15.130225   28900   0.000000
# 2000-07-27  17.5000  17.6250  17.3750  17.5000  15.130225   61200   0.000000
# 2000-07-28  17.5625  17.5625  17.1250  17.3750  15.022151  146100  -0.714293
# 2000-07-31  17.5000  17.6875  16.8750  17.6875  15.292333  178400   1.798555
# 2000-08-01  17.5625  18.4375  17.2500  17.5000  15.130225   87400  -1.060057
# ...             ...      ...      ...      ...        ...     ...        ...
# 2023-05-23  11.2700  11.8800  11.2700  11.4600  11.460000  439900   0.791558
# 2023-05-24  11.4500  11.9000  11.2100  11.7600  11.760000  671400   2.617803
# 2023-05-25  11.7000  11.8500  11.4400  11.6600  11.660000  225200  -0.850343
# 2023-05-26  11.6300  11.8800  11.4500  11.6800  11.680000  252200   0.171531
# 2023-05-30  11.6000  11.7200  11.3650  11.7100  11.710000  130390   0.256847
#
#             variacion_ranking
# Date
# 2000-07-26             2873.0
# 2000-07-27             2873.0
# 2000-07-28             2231.0
# 2000-07-31             4293.0
# 2000-08-01             1949.0
# ...                       ...
# 2023-05-23             3593.0
# 2023-05-24             4710.0
# 2023-05-25             2114.0
# 2023-05-26             3041.0
# 2023-05-30             3119.0
#
# [5747 rows x 8 columns]

# %%
df.sort_values('variacion_ranking', ascending=True).head(10)
# Out:
#                  Open       High    Low  Close  Adj Close    Volume  \
# Date
# 2002-08-27   0.760000   0.760000   0.25   0.26   0.229220    258200
# 2019-08-12  19.309999  19.360001  15.17  16.75  15.502059  30223700
# 2002-06-17   0.320000   0.320000   0.22   0.22   0.193955    632100
# 2008-10-21   2.990000   2.990000   2.22   2.23   1.977409    469300
# 2002-02-01   2.800000   2.800000   2.19   2.27   2.001265    743800
# 2020-03-16   7.720000   8.590000   7.10   7.14   6.608042   2177100
# 2020-03-18   6.910000   7.100000   5.89   6.08   5.627016   2319500
# 2001-09-17   8.500000   8.500000   7.34   7.35   6.479866    406700
# 2002-06-12   0.550000   0.550000   0.38   0.40   0.352646    414700
# 2002-03-25   1.500000   1.500000   1.09   1.12   0.987408     78100
#
#             variacion  variacion_ranking
# Date
# 2002-08-27 -65.789479                1.0
# 2019-08-12 -56.117368                2.0
# 2002-06-17 -31.250016                3.0
# 2008-10-21 -23.890771                4.0
# 2002-02-01 -23.050849                5.0
# 2020-03-16 -22.475574                6.0
# 2020-03-18 -20.418852                7.0
# 2001-09-17 -20.108678                8.0
# 2002-06-12 -20.000007                9.0
# 2002-03-25 -19.999992               10.0

# %% [markdown]
# ## Ranks "percentiles"

# %%
import yfinance as yf
data = yf.download('GGAL')
data['variacion'] = data['Adj Close'].pct_change() *100
data.dropna(inplace=True)
data['variacion_ranking'] = data.variacion.rank()

data['variacion_ranking_pct'] = data.variacion.rank(pct=True)
data.sort_values('variacion_ranking')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High    Low  Close  Adj Close    Volume  \
# Date
# 2002-08-27   0.760000   0.760000   0.25   0.26   0.229220    258200
# 2019-08-12  19.309999  19.360001  15.17  16.75  15.502060  30223700
# 2002-06-17   0.320000   0.320000   0.22   0.22   0.193955    632100
# 2008-10-21   2.990000   2.990000   2.22   2.23   1.977408    469300
# 2002-02-01   2.800000   2.800000   2.19   2.27   2.001265    743800
# ...               ...        ...    ...    ...        ...       ...
# 2002-06-19   0.260000   0.400000   0.24   0.34   0.299749   1002300
# 2002-02-28   1.370000   1.590000   1.12   1.50   1.322422   1038800
# 2002-01-22   2.500000   3.470000   2.45   3.45   3.041570    753900
# 2002-06-20   0.380000   0.650000   0.35   0.59   0.520152   1034600
# 2002-08-28   0.500000   0.810000   0.50   0.75   0.661211    295400
#
#              variacion  variacion_ranking  variacion_ranking_pct
# Date
# 2002-08-27  -65.789476                1.0               0.000174
# 2019-08-12  -56.117365                2.0               0.000348
# 2002-06-17  -31.249996                3.0               0.000522
# 2008-10-21  -23.890776                4.0               0.000696
# 2002-02-01  -23.050844                5.0               0.000870
# ...                ...                ...                    ...
# 2002-06-19   41.666651             5743.0               0.999304
# 2002-02-28   45.631091             5744.0               0.999478
# 2002-01-22   68.292686             5745.0               0.999652
# 2002-06-20   73.529413             5746.0               0.999826
# 2002-08-28  188.461591             5747.0               1.000000
#
# [5747 rows x 9 columns]

# %% [markdown]
# ## Repaso de quantiles, cuartiles, quintiles, deciles, percentiles y blabla_iles

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quantiles

# %%
import yfinance as yf
data = yf.download('GGAL')
data['variacion'] = data['Adj Close'].pct_change() *100
data.dropna(inplace=True)
data['variacion_ranking'] = data.variacion.rank()
data['variacion_ranking_pct'] = data.variacion.rank(pct=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume  variacion  \
# Date
# 2000-07-26  17.2500  17.5625  17.1875  17.5000  15.130221   28900   0.000000
# 2000-07-27  17.5000  17.6250  17.3750  17.5000  15.130221   61200   0.000000
# 2000-07-28  17.5625  17.5625  17.1250  17.3750  15.022150  146100  -0.714275
# 2000-07-31  17.5000  17.6875  16.8750  17.6875  15.292333  178400   1.798562
# 2000-08-01  17.5625  18.4375  17.2500  17.5000  15.130221   87400  -1.060082
# ...             ...      ...      ...      ...        ...     ...        ...
# 2023-05-23  11.2700  11.8800  11.2700  11.4600  11.460000  439900   0.791558
# 2023-05-24  11.4500  11.9000  11.2100  11.7600  11.760000  671400   2.617803
# 2023-05-25  11.7000  11.8500  11.4400  11.6600  11.660000  225200  -0.850343
# 2023-05-26  11.6300  11.8800  11.4500  11.6800  11.680000  252200   0.171531
# 2023-05-30  11.6000  11.7200  11.3650  11.7100  11.710000  130390   0.256847
#
#             variacion_ranking  variacion_ranking_pct
# Date
# 2000-07-26             2873.0               0.499913
# 2000-07-27             2873.0               0.499913
# 2000-07-28             2231.0               0.388203
# 2000-07-31             4293.0               0.746998
# 2000-08-01             1949.0               0.339133
# ...                       ...                    ...
# 2023-05-23             3593.0               0.625196
# 2023-05-24             4710.0               0.819558
# 2023-05-25             2114.0               0.367844
# 2023-05-26             3041.0               0.529146
# 2023-05-30             3119.0               0.542718
#
# [5747 rows x 9 columns]

# %%
data.variacion.quantile(0.529238)
# Out:
# 0.17181582517515284

# %% [markdown]
# ## Ejercicio

# %% [markdown]
#     a - Traer los quantiles 0.05 y 0.95 de las variaciones diarias del SP500 desde el año 2005,
#     b - Calcular el ratio del quantil 95 vs el 5 (en valor absoluto)
#     c - Dar una interpretación de que significa el ratio
#     d - Hacer el mismo cálculo para los siguientes tickers ['AAPL','AMZN','GOOGL','NFLX','GGAL','YPF','PAM']
#     e - Sacar conclusiones
#
#     f - ¿Que tipo de retornos debería tomar? ¿logaritmicos o lineales? ¿Por que?
#
#     g- ¿Que pasa si quiero un ratio mas realista, es decir que contemple no solo los valores quantiles sino el agregado de toda una cola de la distribucion?  ¿Como debería hacer ese cálculo?

# %%
import numpy as np

tickers = ['SPY','AAPL','AMZN','GOOGL','NFLX','GGAL','YPF','PAM']
data = yf.download(tickers, start='2005-01-01', auto_adjust=True)['Close']
pnl = np.log(data / data.shift())
pnl.quantile(.95).divide(pnl.quantile(.05)).abs().round(4)
# Out:
# [*********************100%***********************]  8 of 8 completed
# AAPL     1.0533
# AMZN     1.0717
# GGAL     1.0412
# GOOGL    0.9864
# NFLX     1.1239
# PAM      1.0885
# SPY      0.9131
# YPF      1.0859
# dtype: float64

# %% [markdown]
# # Ideas para practicar

# %% [markdown]
# ### Hipótesis
#
# * Hay una variabildiad importante en los retornos en función del día de semana

# %% [markdown]
# ### Buscamos una lista de tickers

# %%
import pandas as pd

sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sp500_tickers = list(sp500.Symbol)
sp500_tickers = [e for e in sp500_tickers if e not in ('BRK.B','BF.B')]

print(sp500_tickers[:100])
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BG', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY']

# %% [markdown]
# ### Bajamos los cierres diarios de esos tickers

# %%
# %%time

import yfinance as yf
import numpy as np

tickers = sp500_tickers
cierres = yf.download(tickers, start='2000-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  501 of 501 completed
# CPU times: user 30.2 s, sys: 2.24 s, total: 32.4 s
# Wall time: 28.2 s

# %%
pd.options.display.max_columns = 8
cierres
# Out:
#                      A    AAL         AAP        AAPL  ...         ZBH  \
# Date                                                   ...
# 2000-01-03   43.929703    NaN         NaN    0.849469  ...         NaN
# 2000-01-04   40.573956    NaN         NaN    0.777850  ...         NaN
# 2000-01-05   38.057152    NaN         NaN    0.789232  ...         NaN
# 2000-01-06   36.608078    NaN         NaN    0.720933  ...         NaN
# 2000-01-07   39.658745    NaN         NaN    0.755083  ...         NaN
# ...                ...    ...         ...         ...  ...         ...
# 2023-05-23  128.639999  14.07  116.779999  171.559998  ...  130.320007
# 2023-05-24  120.989998  13.80  115.230003  171.839996  ...  128.619995
# 2023-05-25  119.489998  14.38  111.620003  172.990005  ...  127.800003
# 2023-05-26  120.419998  14.35  112.150002  175.429993  ...  127.650002
# 2023-05-30  119.370003  14.51  111.930000  177.270004  ...  126.809998
#
#                   ZBRA       ZION         ZTS
# Date
# 2000-01-03   25.027779  37.010738         NaN
# 2000-01-04   24.666668  35.218548         NaN
# 2000-01-05   25.138889  35.176861         NaN
# 2000-01-06   23.777779  35.677021         NaN
# 2000-01-07   23.513889  35.760372         NaN
# ...                ...        ...         ...
# 2023-05-23  271.220001  29.389999  172.669998
# 2023-05-24  261.390015  28.969999  169.139999
# 2023-05-25  259.690002  28.320000  165.240005
# 2023-05-26  264.720001  28.660000  164.740005
# 2023-05-30  268.480011  28.790001  161.850006
#
# [5889 rows x 501 columns]

# %% [markdown]
# ### Armamos una matriz de retornos y una de resumen

# %%
retornos = np.log((cierres/cierres.shift(1)))

mat_ret = retornos.groupby(retornos.index.dayofweek).mean()*250

mat_ret = mat_ret.clip(lower=-1, upper=1)
mat_ret.index = ['Lunes','Martes','Miercoles','Jueves','Viernes']
resumen = mat_ret.transpose()
resumen.describe()
# Out:
#             Lunes      Martes   Miercoles      Jueves     Viernes
# count  501.000000  501.000000  501.000000  501.000000  501.000000
# mean    -0.066967    0.187877    0.118835    0.141512    0.140931
# std      0.226989    0.184457    0.170570    0.192212    0.194906
# min     -0.816606   -1.000000   -0.482354   -0.447447   -0.544580
# 25%     -0.216468    0.087004    0.010669    0.020492    0.035241
# 50%     -0.066414    0.186499    0.098141    0.127586    0.141988
# 75%      0.065871    0.294251    0.209144    0.249091    0.240621
# max      1.000000    0.864224    1.000000    1.000000    1.000000

# %% [markdown]
# # Persistir objeto serializado

# %% [markdown]
# (Ya lo vamos a ver mas adelante...)

# %%
import pickle

with open('retornos.dat', 'wb') as file:
    pickle.dump(retornos, file)

# %% [markdown]
# # Levantar objeto serializado

# %%
with open('retornos.dat', 'rb') as file:
    retornos_load = pickle.load(file)

# %% [markdown]
# ### Graficamos

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
resumen.hist(figsize=(15,10), bins=100)
# Out:
# array([[<Axes: title={'center': 'Lunes'}>,
#         <Axes: title={'center': 'Martes'}>],
#        [<Axes: title={'center': 'Miercoles'}>,
#         <Axes: title={'center': 'Jueves'}>],
#        [<Axes: title={'center': 'Viernes'}>, <Axes: >]], dtype=object)

# %%
resumen.rolling(20).mean().plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
df1 = resumen['Lunes'].rolling(20).mean()
df2 = resumen['Martes'].rolling(20).mean()
df3 = resumen['Miercoles'].rolling(20).mean()

df_todos=  pd.concat([df1,df2,df3], axis=1)
df_todos.plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

for dia in resumen.columns:
    resumen[dia].rolling(20).mean().plot()


plt.legend(loc='upper left')

# %%
resumen.Lunes.plot(kind='hist', bins=100, grid=True, figsize=(12,4), range=(-1,1))
# Out:
# <Axes: ylabel='Frequency'>

# %%
resumen.Martes.plot(kind='hist', bins=100, grid=True, figsize=(12,4), range=(-1,1))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### BoxPlot

# %%
pd.plotting.boxplot_frame(resumen, whis=1.5, showmeans=True, figsize=(12,7))
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Funciones Acumulativas

# %% [markdown]
# Las funciones acumulativas nos permiten trabajar en la fila "n" de una tabla con todos los datos de las filas "0 a n"
# <br>Dentro de este tipo de funciones encontramos:

# %% [markdown]
# * cummax()  El máximo acumulado (ideal para máximo histórico por fecha)
# * cummin()  El mínimo acumulado (ideal para mínimo histórico por fecha)
# * cumsum() La suma acumulada (ideal para armado se subtotales por fecha)
# * cumprod() El producto acumulado (ideal para rendimiento compuesto)

# %% [markdown]
# ## Cummax()

# %% [markdown]
# El uso típico que le vamos a dar a esta función es para saber el máximo histórico de una serie en cada punto de la misma

# %%
data = yf.download('GGAL', auto_adjust=True)
data = data.drop(["High","Low","Volume"], axis=1)

data['maxHist'] = data.Close.cummax()
data.head(6)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open      Close    maxHist
# Date
# 2000-07-25  15.116714  15.130223  15.130223
# 2000-07-26  14.914077  15.130223  15.130223
# 2000-07-27  15.130223  15.130223  15.130223
# 2000-07-28  15.184259  15.022149  15.130223
# 2000-07-31  15.130222  15.292332  15.292332
# 2000-08-01  15.184260  15.130223  15.292332

# %%
data.maxHist.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Cummin()

# %% [markdown]
# Obviamente es lo mismo que el cummax pero para mínimos, la combinación de cummax() y cummin() va a ser muy util para backtestings de drawdowns y recuperaciones posteriores

# %%
data['minHist'] = data.Close.cummin()
data.head(6)
# Out:
#                  Open      Close    maxHist    minHist
# Date
# 2000-07-25  15.116714  15.130223  15.130223  15.130223
# 2000-07-26  14.914077  15.130223  15.130223  15.130223
# 2000-07-27  15.130223  15.130223  15.130223  15.130223
# 2000-07-28  15.184259  15.022149  15.130223  15.022149
# 2000-07-31  15.130222  15.292332  15.292332  15.022149
# 2000-08-01  15.184260  15.130223  15.292332  15.022149

# %%
data.iloc[:, -3: ].plot(logy=True)
# Out:
# <Axes: xlabel='Date'>

# %%
data = yf.download('YPF', auto_adjust=True)
data['maxHist'] = data.Close.cummax()
data['minHist'] = data.Close.cummin()
data = data.drop(["High","Low","Volume"], axis=1)
data.iloc[:, -3: ].plot(logy=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Cumsum()

# %% [markdown]
# Cumsum() es obviamente una funcion de sumas acumuladas, que en la posicion de la fila "n" nos devuelve la suma de "0 a n" (inclusive)

# %% [markdown]
# $$ \large cumsum\hspace{3mm}(X_{n})\hspace{3mm}  =  \hspace{3mm} \sum_{i=0}^{n}x_{i} $$

# %% [markdown]
# En el ejemplo aprovechamos para borrar las columnas de OHLC par limpiar un poco la salida con la función drop()

# %%
data = yf.download('GGAL', auto_adjust=True)
data['volumenAcum'] = data.Volume.cumsum()/1000000
data = data.drop(['Open','High','Low','Close'], axis=1).dropna().round(2)
data.head(6)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Volume  volumenAcum
# Date
# 2000-07-25  126200         0.13
# 2000-07-26   28900         0.16
# 2000-07-27   61200         0.22
# 2000-07-28  146100         0.36
# 2000-07-31  178400         0.54
# 2000-08-01   87400         0.63

# %%
data.volumenAcum.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Cumprod()

# %% [markdown]
# Cumprod() es una función de productorio, es decir el producto acumulado de 0 a n, para la fila n

# %% [markdown]
# $$ \large cumprod\hspace{3mm}(X_{n})\hspace{3mm}  =  \hspace{3mm} \prod_{i=0}^{n}x_{i} $$

# %% [markdown]
# Vamos a usar esta fórmula para calcular rendimiento compuesto, es muy sencillo:
# <br>  1- Creamos una columna "variacion" con el valor "r", rendimiento porcentual diario.
# <br>  2- Creamos una columna "factor" con el valor (1+r)
# <br>  2- Luego vamos a aplicar el productorio para cada fila de esa columna "factor" y le restamos 1 al resultado.

# %%
data = yf.download('GGAL', auto_adjust=True)

data['variacion'] = data['Close'].pct_change()
data['factor'] = 1 + data['variacion']
data['rendimientoAcum'] = (data.factor.cumprod()-1)*100
data['base100'] = (data.factor.cumprod())*100

data = data.drop(['Open','High','Low','Close','Volume'],axis=1).dropna().round(4)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#             variacion  factor  rendimientoAcum   base100
# Date
# 2000-07-26     0.0000  1.0000           0.0000  100.0000
# 2000-07-27     0.0000  1.0000           0.0000  100.0000
# 2000-07-28    -0.0071  0.9929          -0.7143   99.2857
# 2000-07-31     0.0180  1.0180           1.0714  101.0714
# 2000-08-01    -0.0106  0.9894          -0.0000  100.0000
# ...               ...     ...              ...       ...
# 2023-05-23     0.0079  1.0079         -24.2576   75.7424
# 2023-05-24     0.0262  1.0262         -22.2748   77.7252
# 2023-05-25    -0.0085  0.9915         -22.9357   77.0643
# 2023-05-26     0.0017  1.0017         -22.8035   77.1965
# 2023-05-30     0.0026  1.0026         -22.6052   77.3948
#
# [5747 rows x 4 columns]

# %%
data.rendimientoAcum.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.base100.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Algo mas avanzado de MatPlotLib

# %%
import matplotlib.pyplot as plt


import matplotlib.dates as mdates
from datetime import datetime as dtdt

fig, ax = plt.subplots(figsize=(10,5))

# Ploteo
curva = data.rendimientoAcum.rolling(30).mean()

# c es color
# ls es linestyle
# lw es linewidth

ax.plot(curva, c='k', ls='-', lw=.5, label='GGAL Buy&Hold desde año 2000')

ax.fill_between(data.index, curva, 0, where=curva < 0 ,color='pink')
ax.fill_between(data.index, curva, 0, where=curva > 0 ,color='lightgreen')

ax.legend(loc='upper left', fontsize=15)

# ticks y labels
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=18))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.tick_params(axis='x', rotation=45, labelsize=10, width=5)
ax.grid()

# Anotaciones
eventos = { "Elecc 2015": dtdt(2015,10,23), "  28-D" : dtdt(2017,12,28),  '  PRE-PASO' : dtdt(2019,8,9) }
for k,v in eventos.items():
    ax.plot(eventos[k], data.loc[v].rendimientoAcum, 'ko', markersize=15, alpha=.3)
    ax.annotate(k, xy=(v,data.loc[v].rendimientoAcum), fontsize=14)

# %% [markdown]
# ## Rolling vs Acumulativas vs Descriptivas (diferencias)
# * cummax vs rolling(n).max() vs max()
# * cummin vs rolling(n).min() vs min()
# * cumsum vs rolling(n).sum() vs sum()

# %% [markdown]
# ## Reflexionar diferencias y casos de uso

# %% [markdown]
# look-ahead Bias, leakage

# %% [markdown]
# # Agrupamiento

# %%
data = yf.download('GGAL', auto_adjust=True)
data['variacion'] = data['Close'].pct_change()
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Volume  variacion
# Date
# 2000-07-25  15.116712  15.346367  14.481783  15.130221  126200        NaN
# 2000-07-26  14.914075  15.184258  14.860039  15.130221   28900   0.000000
# 2000-07-27  15.130221  15.238294  15.022148  15.130221   61200   0.000000
# 2000-07-28  15.184259  15.184259  14.806003  15.022149  146100  -0.007143
# 2000-07-31  15.130226  15.292336  14.589861  15.292336  178400   0.017986
# ...               ...        ...        ...        ...     ...        ...
# 2023-05-23  11.270000  11.880000  11.270000  11.460000  439900   0.007916
# 2023-05-24  11.450000  11.900000  11.210000  11.760000  671400   0.026178
# 2023-05-25  11.700000  11.850000  11.440000  11.660000  225200  -0.008503
# 2023-05-26  11.630000  11.880000  11.450000  11.680000  252200   0.001715
# 2023-05-30  11.600000  11.720000  11.365000  11.710000  130533   0.002568
#
# [5748 rows x 6 columns]

# %% [markdown]
# ## Agrupamiento - Indices de fechas

# %% [markdown]
# ### Por día de la semana

# %%
agrupados = data.Volume.groupby(data.index.dayofweek).sum()
agrupados
# Out:
# Date
# 0    517166100
# 1    603517133
# 2    587784000
# 3    587461700
# 4    549717700
# Name: Volume, dtype: int64

# %% [markdown]
# ### Por trimestre

# %%
agrupados = data.Close.groupby(data.index.to_period('Q')).last()
agrupados
# Out:
# Date
# 2000Q3    12.968761
# 2000Q4    12.806653
# 2001Q1    13.279316
# 2001Q2    12.977363
# 2001Q3     5.245605
#             ...
# 2022Q2     6.789971
# 2022Q3     7.419211
# 2022Q4     9.676799
# 2023Q1    10.980000
# 2023Q2    11.710000
# Freq: Q-DEC, Name: Close, Length: 92, dtype: float64

# %% [markdown]
# ### Por año

# %%
agrupados = data.variacion.groupby(data.index.to_period('Y')).mean()
agrupados.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Por mas de un criterio

# %%
agrupados = data.groupby([data.index.year, data.index.dayofweek]).sum()
agrupados.head(20)
# Out:
#                  Open        High         Low       Close    Volume  variacion
# Date Date
# 2000 0     259.861576  262.887621  254.836181  259.267175   2192700  -0.009998
#      1     302.658484  307.521770  297.200797  302.442338   3635400  -0.026301
#      2     301.077919  305.427858  293.539826  299.105586   3892700  -0.258724
#      3     287.095981  294.269328  282.975697  289.689734   6454200   0.249279
#      4     302.401822  306.711234  296.768516  300.659144   5101400  -0.073089
# 2001 0     489.146885  498.559370  478.062649  485.381761  25017500  -0.230102
#      1     542.994407  553.602771  530.433043  538.830019  30585500  -0.201903
#      2     530.080895  542.011110  516.030226  528.037255  35334500   0.011190
#      3     537.499146  546.915318  522.922827  534.473180  39503100  -0.291066
#      4     524.280524  533.609049  508.463555  520.091256  35556000  -0.533959
# 2002 0      52.870413   55.471176   49.969902   52.129857   7069200  -0.582782
#      1      57.216772   60.593355   54.095858   57.322566   9342000   0.272973
#      2      56.555563   59.006450   52.553033   55.709213  13592700   1.072332
#      3      56.044226   59.544235   52.764621   56.185285  16666100   1.875244
#      4      56.837680   59.940962   52.791070   55.762110  14014400  -0.443121
# 2003 0     174.189368  178.958902  169.816560  174.885842   9021300   0.385512
#      1     186.814080  191.213338  180.775024  187.528190  12039400   0.715601
#      2     187.431219  191.927452  182.291404  186.805272  14062800  -0.090099
#      3     171.632691  176.437490  167.418573  171.888358  12791800   0.052751
#      4     177.283837  181.885864  173.413549  178.059658  11952200   0.324363

# %%
# Ojo con los multi-indices

# %% [markdown]
# ## Agrupamientos lógicos y variables categóricas

# %% [markdown]
# ###  Ejercicio de repaso
#
# Dado el diccionario que representa los valores tope de "segmentos de volatilidad":
#
#        regimenes = {'Baja':0.4, 'Media':.6, 'Alta':99}
#
# Crear una lista de los delimitadores de cada segmento que comience por 0

# %% [markdown]
# ### Segmentación

# %%
data = yf.download('GGAL', auto_adjust=True)

data['variacion'] = data['Close'].pct_change()
data['volatilidad'] = data.variacion.rolling(250).std() * 250**0.5
data.dropna(inplace=True)

regimenes = {'Baja':0.4, 'Media':.6, 'Alta':99}
bins = [0] + list(regimenes.values())

data['regimen'] = pd.cut(data.volatilidad, bins=bins, labels=list(regimenes.keys()))
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close   Volume  variacion  \
# Date
# 2001-07-23  10.508845  10.561741   9.794737   9.909347  1151900   0.027422
# 2001-07-24   9.882897   9.882897   9.406825   9.433273   518800  -0.048043
# 2001-07-25   9.256951   9.424458   9.018915   9.301032  1405300  -0.014019
# 2001-07-26   9.133524   9.212869   8.948385   9.054179   741000  -0.026540
# 2001-07-27   8.966019   9.212871   8.727983   9.133526  2540300   0.008764
# ...               ...        ...        ...        ...      ...        ...
# 2023-05-23  11.270000  11.880000  11.270000  11.460000   439900   0.007916
# 2023-05-24  11.450000  11.900000  11.210000  11.760000   671400   0.026178
# 2023-05-25  11.700000  11.850000  11.440000  11.660000   225200  -0.008503
# 2023-05-26  11.630000  11.880000  11.450000  11.680000   252200   0.001715
# 2023-05-30  11.600000  11.720000  11.365000  11.710000   130533   0.002568
#
#             volatilidad regimen
# Date
# 2001-07-23     0.558951   Media
# 2001-07-24     0.560919   Media
# 2001-07-25     0.561063   Media
# 2001-07-26     0.561600   Media
# 2001-07-27     0.561356   Media
# ...                 ...     ...
# 2023-05-23     0.514238   Media
# 2023-05-24     0.514834   Media
# 2023-05-25     0.514931   Media
# 2023-05-26     0.514925   Media
# 2023-05-30     0.514550   Media
#
# [5498 rows x 8 columns]

# %%
data.groupby('regimen').size()
# Out:
# regimen
# Baja     1212
# Media    2700
# Alta     1586
# dtype: int64

# %% [markdown]
# ### Ejercicio
#
#     Con esta matriz, extraer la variación diaria que delimita al primer y último decil de cada régimen de volatilidad
#     Razonar utilidad de este tipo de ejercicio

# %% [markdown]
# ## Métodos para concatenar a los agrupamientos

# %% [markdown]
# Así como usamos la funcón count() podemos usar otro tipo de funciones, por ejemplo:
# * first()
# * last()
# * min()
# * max()
# * sum()
# * prod()
# * mean()
# * median()
# * std() desvio estandar (sigma)
# * var() varianza (sigma^2)
# * skew()  (Coeficiente de asimetria)
# * kurtosis()
# * quantile()

# %% [markdown]
# # Mas funciones

# %% [markdown]
# ## Clip (Acotado)

# %%
tabla = yf.download(['AAPL','SPY','QQQ'], auto_adjust=True)['Close'].pct_change().dropna() *100
tabla
# Out:
# [*********************100%***********************]  3 of 3 completed
#                 AAPL       QQQ       SPY
# Date
# 1999-03-11 -1.151909  0.489585  1.112742
# 1999-03-12  3.106941 -2.436077 -0.956976
# 1999-03-15  2.636317  2.871478  1.425139
# 1999-03-16  4.220300  0.849415 -0.381046
# 1999-03-17 -4.049403 -0.721985 -0.430270
# ...              ...       ...       ...
# 2023-05-23 -1.515499 -1.267631 -1.122284
# 2023-05-24  0.163207 -0.512956 -0.724480
# 2023-05-25  0.669233  2.433290  0.865990
# 2023-05-26  1.410479  2.555043  1.295067
# 2023-05-30  1.003255  0.711829  0.076189
#
# [6095 rows x 3 columns]

# %%
tabla_acotada = tabla.clip(-4,4)
tabla_acotada
# Out:
#                 AAPL       QQQ       SPY
# Date
# 1999-03-11 -1.151909  0.489585  1.112742
# 1999-03-12  3.106941 -2.436077 -0.956976
# 1999-03-15  2.636317  2.871478  1.425139
# 1999-03-16  4.000000  0.849415 -0.381046
# 1999-03-17 -4.000000 -0.721985 -0.430270
# ...              ...       ...       ...
# 2023-05-23 -1.515499 -1.267631 -1.122284
# 2023-05-24  0.163207 -0.512956 -0.724480
# 2023-05-25  0.669233  2.433290  0.865990
# 2023-05-26  1.410479  2.555043  1.295067
# 2023-05-30  1.003255  0.711829  0.076189
#
# [6095 rows x 3 columns]

# %% [markdown]
# # Repaso de Estadística

# %% [markdown]
# ## Desvío Estandrar - Fórmulas

# %% [markdown]
# El desvio es el sigma, la varianza es el sigma cuadrado

# %% [markdown]
# $$ \large \sigma^2 = \frac{1}{n}  \sum_{x=i}^{n} . (X_i - \bar{X} )^2  $$

# %%
tabla.std()
# Out:
# AAPL    2.553220
# QQQ     1.744783
# SPY     1.241703
# dtype: float64

# %% [markdown]
# ## Error estandar - Fórmulas

# %% [markdown]
# $$ \Large \frac{\sigma}{\sqrt{n}}$$

# %%
tabla.sem()
# Out:
# AAPL    0.032704
# QQQ     0.022349
# SPY     0.015905
# dtype: float64

# %% [markdown]
# ## Varianza

# %%
tabla.std()**2
# Out:
# AAPL    6.518931
# QQQ     3.044268
# SPY     1.541827
# dtype: float64

# %%
tabla.var()
# Out:
# AAPL    6.518931
# QQQ     3.044268
# SPY     1.541827
# dtype: float64

# %% [markdown]
# ## Skew - Fórmulas

# %% [markdown]
# $$ \large  skew =  \frac{\mu_3}{\sigma^3}  =  \frac{\sum_{x=i}^{n} \frac{1}{n} . (X_i - \bar{X} )^3}{\sigma^3} $$

# %% [markdown]
# ## Repaso de Coeficiente de Asimetría

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Kurtosis

# %% [markdown]
# $$ \Large kurtosis = \frac{\sum_{i=1} (X_i-\bar{X})^4}{n . \sigma^4}$$

# %% [markdown]
# Coeficiente de apuntamiento
#
# <div style="width:600px;float:left;">
#     <br>La Curtosis nos da una idea de la forma, mientras mas alta, mas valores cerca de la media y mas gruesas las colas
#     <ul>
#         <li> Leptocúrtica,  Curtosis > 3 (más apuntada y con colas más gruesas que la normal) </li>
#         <li> Platicúrtica,  Curtosis < 3 (menos apuntada y con colas menos gruesas que la norma) </li>
#         <li> Mesocúrtica,   Curtosis = 3 (tiene una distribución normal) </li>
#     </ul>
# </div>
# <div style="width:350px;float:right;margin-top:-25px;">
#     <img src="./imagenes/kurtosis.png" style="width:300px;height:230px;">
# </div>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tabla.kurt()
# Out:
# AAPL    31.830751
# QQQ      6.736130
# SPY     11.125343
# dtype: float64

# %%
tabla.skew()
# Out:
# AAPL   -1.285874
# QQQ     0.214783
# SPY    -0.004426
# dtype: float64

# %%
tabla.var()
# Out:
# AAPL    6.518931
# QQQ     3.044268
# SPY     1.541827
# dtype: float64

# %% [markdown]
# ## Covarianza

# %% [markdown]
# $$ \large s_{xy}={1 \over n}\sum _{i=1}^{n}{(x_{i}-{\overline {x}})(y_{i}-{\overline {y}})} $$

# %%
import yfinance as yf

activos = ['GGAL','YPF','PAM','EDN','BBAR']
data = yf.download(activos, start='2001-01-01', end='2020-08-30')['Adj Close']
tabla = data.pct_change().dropna()*100
tabla
# Out:
# [*********************100%***********************]  5 of 5 completed
#                 BBAR       EDN      GGAL       PAM       YPF
# Date
# 2009-10-12  4.817494  5.421684  1.698085  1.176460 -0.656068
# 2009-10-13 -1.114190  1.714281  0.371056 -2.015496  1.447801
# 2009-10-14 -1.408448  0.000000  2.587800 -0.474681  0.300471
# 2009-10-15 -0.857149 -1.460665 -2.702711 -0.635937  1.098323
# 2009-10-16 -3.314129  1.368300 -1.666630  0.400004 -0.296304
# ...              ...       ...       ...       ...       ...
# 2020-08-24 -0.903612 -5.660378 -0.494553  0.363967  0.934583
# 2020-08-25  1.823712 -2.857140  1.093441  1.450588  2.777779
# 2020-08-26 -3.283584  1.470587 -1.278291  2.234138  0.180176
# 2020-08-27 -0.617285  1.449274 -1.394418  0.611894 -3.237407
# 2020-08-28  8.695653  4.285717  7.070717  4.170283  6.133827
#
# [2740 rows x 5 columns]

# %%
tabla.GGAL.cov(tabla.GGAL)
# Out:
# 12.46561018404195

# %%
tabla.GGAL.cov(tabla.EDN)
# Out:
# 7.626181332629053

# %% [markdown]
# ### Matriz de covarianzas

# %%
tabla.cov()
# Out:
#            BBAR        EDN       GGAL       PAM       YPF
# BBAR  12.709457   7.705112  10.337802  7.336795  5.841315
# EDN    7.705112  16.075827   7.626181  7.554618  5.075764
# GGAL  10.337802   7.626181  12.465610  7.344022  6.085248
# PAM    7.336795   7.554618   7.344022  9.924349  4.742025
# YPF    5.841315   5.075764   6.085248  4.742025  9.376966

# %%
tabla.corr()
# Out:
#           BBAR       EDN      GGAL       PAM       YPF
# BBAR  1.000000  0.539050  0.821312  0.653269  0.535077
# EDN   0.539050  1.000000  0.538721  0.598101  0.413412
# GGAL  0.821312  0.538721  1.000000  0.660277  0.562847
# PAM   0.653269  0.598101  0.660277  1.000000  0.491566
# YPF   0.535077  0.413412  0.562847  0.491566  1.000000
